# %% [markdown]
# # Crypto API

# %%
 #This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '5ab21e2b-27af-45b7-932c-a6be562be5d0',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2023-05-18T21:03:01.404Z', 'error_code': 0, 'error_message': None, 'elapsed': 285, 'credit_count': 1, 'notice': None, 'total_count': 9690}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10216, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'p
# ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_28600\315520502.py:7: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['timestamp'] = pd.to_datetime('now')
#       id         name symbol          slug  num_market_pairs  \
# 0      1      Bitcoin    BTC       bitcoin             10216
# 1   1027     Ethereum    ETH      ethereum              6914
# 2    825       Tether   USDT        tether             53688
# 3   1839          BNB    BNB           bnb              1378
# 4   3408     USD Coin   USDC      usd-coin             12538
# 5     52          XRP    XRP           xrp               950
# 6   2010      Cardano    ADA       cardano               789
# 7     74     Dogecoin   DOGE      dogecoin               710
# 8   5426       Solana    SOL        solana               463
# 9   3890      Polygon  MATIC       polygon               705
# ...

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '5ab21e2b-27af-45b7-932c-a6be562be5d0',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    
    df = pd.json_normalize(data['data'])
    df['timestamp'] = pd.to_datetime('now')
    df
    
    if not os.path.isfile(r'C:\Users\PC\Python Scripts\API.csv'):
        df.to_csv(r'C:\Users\PC\Python Scripts\API.csv', header='column_names')
    else:
        df.to_csv(r'C:\Users\PC\Python Scripts\API.csv', mode='a', header=False)

# %%
import os
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60)
exit()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_28600\386282440.py:25: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['timestamp'] = pd.to_datetime('now')
# API Runner completed
# C:\Users\PC\AppData\Local\Temp\ipykernel_28600\386282440.py:25: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['timestamp'] = pd.to_datetime('now')
# API Runner completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 8
#       6     api_runner()
#       7     print('API Runner completed')
# ----> 8     sleep(60)
#       9 exit()
#
# KeyboardInterrupt:

# %%
df72 = pd.read_csv(r'C:\Users\PC\Python Scripts\API.csv')
df72
# Out:
#     Unnamed: 0    id         name symbol          slug  num_market_pairs  \
# 0            0     1      Bitcoin    BTC       bitcoin             10216
# 1            1  1027     Ethereum    ETH      ethereum              6914
# 2            2   825       Tether   USDT        tether             53688
# 3            3  1839          BNB    BNB           bnb              1378
# 4            4  3408     USD Coin   USDC      usd-coin             12539
# 5            5    52          XRP    XRP           xrp               950
# 6            6  2010      Cardano    ADA       cardano               789
# 7            7    74     Dogecoin   DOGE      dogecoin               710
# 8            8  5426       Solana    SOL        solana               463
# 9            9  3890      Polygon  MATIC       polygon               705
# 10          10     2     Litecoin    LTC      litecoin               912
# 11          11  1958         TRON    TRX          tron               759
# ...

# %%
df
# Out:
#       id         name symbol          slug  num_market_pairs  \
# 0      1      Bitcoin    BTC       bitcoin             10216
# 1   1027     Ethereum    ETH      ethereum              6914
# 2    825       Tether   USDT        tether             53688
# 3   1839          BNB    BNB           bnb              1378
# 4   3408     USD Coin   USDC      usd-coin             12538
# 5     52          XRP    XRP           xrp               950
# 6   2010      Cardano    ADA       cardano               789
# 7     74     Dogecoin   DOGE      dogecoin               710
# 8   5426       Solana    SOL        solana               463
# 9   3890      Polygon  MATIC       polygon               705
# 10     2     Litecoin    LTC      litecoin               912
# 11  1958         TRON    TRX          tron               759
# 12  6636     Polkadot    DOT  polkadot-new               502
# 13  4687  Binance USD   BUSD   binance-usd              6772
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
#       id         name symbol          slug  num_market_pairs  \
# 0      1      Bitcoin    BTC       bitcoin             10216
# 1   1027     Ethereum    ETH      ethereum              6914
# 2    825       Tether   USDT        tether             53688
# 3   1839          BNB    BNB           bnb              1378
# 4   3408     USD Coin   USDC      usd-coin             12539
# 5     52          XRP    XRP           xrp               950
# 6   2010      Cardano    ADA       cardano               789
# 7     74     Dogecoin   DOGE      dogecoin               710
# 8   5426       Solana    SOL        solana               463
# 9   3890      Polygon  MATIC       polygon               705
# 10     2     Litecoin    LTC      litecoin               912
# 11  1958         TRON    TRX          tron               759
# 12  6636     Polkadot    DOT  polkadot-new               502
# 13  4687  Binance USD   BUSD   binance-usd              6772
# ...

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h', 'quote.USD.percent_change_7d', 'quote.USD.percent_change_30d', 'quote.USD.percent_change_60d', 'quote.USD.percent_change_90d']].mean()

# %%
df3
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                          0.34361                      -2.21732
# Ethereum                         0.25141                      -1.42782
# Tether                           0.01278                       0.00090
# BNB                              0.26728                      -1.69967
# USD Coin                        -0.01898                      -0.03083
# XRP                              1.24687                       3.62506
# Cardano                          0.52237                      -0.86959
# Dogecoin                         0.52370                      -3.22132
# Solana                           0.41605                      -3.07533
# Polygon                          0.58718                      -3.71150
# Litecoin                         1.08990                      -3.25841
# TRON                             0.23609                      -0.87425
# ...

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin      quote.USD.percent_change_1h      0.34361
#              quote.USD.percent_change_24h    -2.21732
#              quote.USD.percent_change_7d     -0.69506
#              quote.USD.percent_change_30d   -11.60659
#              quote.USD.percent_change_60d    -4.83329
#              quote.USD.percent_change_90d     8.58591
# Ethereum     quote.USD.percent_change_1h      0.25141
#              quote.USD.percent_change_24h    -1.42782
#              quote.USD.percent_change_7d      0.32036
#              quote.USD.percent_change_30d   -13.85667
#              quote.USD.percent_change_60d    -0.55675
#              quote.USD.percent_change_90d     5.49513
# Tether       quote.USD.percent_change_1h      0.01278
#              quote.USD.percent_change_24h     0.00090
#              quote.USD.percent_change_7d     -0.02681
#              quote.USD.percent_change_30d    -0.00608
#              quote.USD.percent_change_60d    -0.29782
# ...

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                             values
# name
# Bitcoin     quote.USD.percent_change_1h    0.34361
#             quote.USD.percent_change_24h  -2.21732
#             quote.USD.percent_change_7d   -0.69506
#             quote.USD.percent_change_30d -11.60659
#             quote.USD.percent_change_60d  -4.83329
#             quote.USD.percent_change_90d   8.58591
# Ethereum    quote.USD.percent_change_1h    0.25141
#             quote.USD.percent_change_24h  -1.42782
#             quote.USD.percent_change_7d    0.32036
#             quote.USD.percent_change_30d -13.85667
#             quote.USD.percent_change_60d  -0.55675
#             quote.USD.percent_change_90d   5.49513
# Tether      quote.USD.percent_change_1h    0.01278
#             quote.USD.percent_change_24h   0.00090
#             quote.USD.percent_change_7d   -0.02681
#             quote.USD.percent_change_30d  -0.00608
#             quote.USD.percent_change_60d  -0.29782
# ...

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
index = pd.Index(range(90))

df6 = df5.reset_index()
df6
# Out:
#            name                       level_1    values
# 0       Bitcoin   quote.USD.percent_change_1h   0.34361
# 1       Bitcoin  quote.USD.percent_change_24h  -2.21732
# 2       Bitcoin   quote.USD.percent_change_7d  -0.69506
# 3       Bitcoin  quote.USD.percent_change_30d -11.60659
# 4       Bitcoin  quote.USD.percent_change_60d  -4.83329
# 5       Bitcoin  quote.USD.percent_change_90d   8.58591
# 6      Ethereum   quote.USD.percent_change_1h   0.25141
# 7      Ethereum  quote.USD.percent_change_24h  -1.42782
# 8      Ethereum   quote.USD.percent_change_7d   0.32036
# 9      Ethereum  quote.USD.percent_change_30d -13.85667
# 10     Ethereum  quote.USD.percent_change_60d  -0.55675
# 11     Ethereum  quote.USD.percent_change_90d   5.49513
# 12       Tether   quote.USD.percent_change_1h   0.01278
# 13       Tether  quote.USD.percent_change_24h   0.00090
# 14       Tether   quote.USD.percent_change_7d  -0.02681
# 15       Tether  quote.USD.percent_change_30d  -0.00608
# ...

# %%
df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#            name                percent_change    values
# 0       Bitcoin   quote.USD.percent_change_1h   0.34361
# 1       Bitcoin  quote.USD.percent_change_24h  -2.21732
# 2       Bitcoin   quote.USD.percent_change_7d  -0.69506
# 3       Bitcoin  quote.USD.percent_change_30d -11.60659
# 4       Bitcoin  quote.USD.percent_change_60d  -4.83329
# 5       Bitcoin  quote.USD.percent_change_90d   8.58591
# 6      Ethereum   quote.USD.percent_change_1h   0.25141
# 7      Ethereum  quote.USD.percent_change_24h  -1.42782
# 8      Ethereum   quote.USD.percent_change_7d   0.32036
# 9      Ethereum  quote.USD.percent_change_30d -13.85667
# 10     Ethereum  quote.USD.percent_change_60d  -0.55675
# 11     Ethereum  quote.USD.percent_change_90d   5.49513
# 12       Tether   quote.USD.percent_change_1h   0.01278
# 13       Tether  quote.USD.percent_change_24h   0.00090
# 14       Tether   quote.USD.percent_change_7d  -0.02681
# 15       Tether  quote.USD.percent_change_30d  -0.00608
# ...

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d', 'quote.USD.percent_change_30d', 'quote.USD.percent_change_60d', 'quote.USD.percent_change_90d'],['1h','24h','7d','30d','60d','90d'])
df7
# Out:
#            name percent_change    values
# 0       Bitcoin             1h   0.34361
# 1       Bitcoin            24h  -2.21732
# 2       Bitcoin             7d  -0.69506
# 3       Bitcoin            30d -11.60659
# 4       Bitcoin            60d  -4.83329
# 5       Bitcoin            90d   8.58591
# 6      Ethereum             1h   0.25141
# 7      Ethereum            24h  -1.42782
# 8      Ethereum             7d   0.32036
# 9      Ethereum            30d -13.85667
# 10     Ethereum            60d  -0.55675
# 11     Ethereum            90d   5.49513
# 12       Tether             1h   0.01278
# 13       Tether            24h   0.00090
# 14       Tether             7d  -0.02681
# 15       Tether            30d  -0.00608
# 16       Tether            60d  -0.29782
# 17       Tether            90d   0.00102
# 18          BNB             1h   0.26728
# 19          BNB            24h  -1.69967
# 20          BNB             7d   0.55879
# 21          BNB            30d  -9.79570
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')

# %%
# there was not enough data collected to properly visualize this example but I wrote the code anyway

df9 = df[['name','quote.USD.price','timestamp']]
df9 = df9.query("name == 'Bitcoin'")
df9
# Out:
#       name  quote.USD.price                  timestamp
# 0  Bitcoin      26830.35474 2023-05-18 21:33:08.305762

# %%
# there was not enough data collected to properly visualize this example but I wrote the code anyway

sns.set_theme(style="darkgrid")
sns.lineplot(x='timestamp', y='quote.USD.price', data=df10)
# Out:
# <Axes: xlabel='timestamp', ylabel='quote.USD.price'>
