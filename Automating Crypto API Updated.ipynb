# %% [markdown]
# # Crypto API

# %%
 #This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '5ab21e2b-27af-45b7-932c-a6be562be5d0',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# {'status': {'timestamp': '2023-05-22T23:53:27.104Z', 'error_code': 0, 'error_message': None, 'elapsed': 46, 'credit_count': 1, 'notice': None, 'total_count': 9886}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 10221, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem'], 'max_supply': 21000000, 'circulating_supply': 19380900, 'total_supply': 19380900, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-05-22T23:52:00.000Z', 'quote': {'USD': {'price': 26860.295890737194, 'volume_24h': 11066935108.872486, 'volume_change_24h': 28.0691, 'percent_change_1h': -0.07305545, 'percent_change_24h': 0.309615, 'percent_change_7d': -1.18366236, 'percent_change_30d': -3.41349238, 'percent_change_60d': -5.20123635, 'percent_change_90d': 10.0712207, 'market_cap': 520576708628.7885, 'market_cap_dominance': 46.3096, 'fully_diluted_market_cap': 564066213705.48, 'tvl': None, 'last_updated': '2023-05-22T23:52:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 6933, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'injective-ecosystem', 'layer-1'], 'max_supply': None, 'circulating_supply': 120269409.46943043, 'total_supply': 120269409.46943043, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2023-05-22T23:52:00.000Z', 'quote': {'USD': {'price': 1818.1866653661114, 'volume_24h': 4542420760.670645, 'volume_change_24h': 34.2648, 'percent_change_1h': -0.06304631, 'percent_change_24h': 0.69539813, 'percent_change_7d': 0.04798837, 'percent_change_30d': -2.99933114, 'percent_change_60d': 0.08909383, 'percent_change_90d': 9.77786331, 'market_cap': 218672236548.77515, 'market_cap_dominance': 19.4527, 'fully_diluted_market_cap': 218672236548.78, 'tvl': None, 'last_updated': '2023-05-22T23:52:00.000Z'}}}, {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 53878, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['payments', 'stablecoin', 'asset-backed-stablecoin', 'avalanche-ecosystem', 'solana-ecosystem', 'arbitrum-ecosytem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain', 'usd-stablecoin', 'optimism-ecosystem'], 'max_supply': None, 'circulating_supply': 82919078535.20427, 'total_supply': 86090638895.05328, 'platform': {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH',  ...

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_24360\315520502.py:7: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['timestamp'] = pd.to_datetime('now')
#       id         name symbol          slug  num_market_pairs  \
# 0      1      Bitcoin    BTC       bitcoin             10221
# 1   1027     Ethereum    ETH      ethereum              6933
# 2    825       Tether   USDT        tether             53878
# 3   1839          BNB    BNB           bnb              1387
# 4   3408     USD Coin   USDC      usd-coin             12582
# 5     52          XRP    XRP           xrp               951
# 6   2010      Cardano    ADA       cardano               790
# 7     74     Dogecoin   DOGE      dogecoin               711
# 8   3890      Polygon  MATIC       polygon               709
# 9   5426       Solana    SOL        solana               463
# 10  1958         TRON    TRX          tron               759
# 11     2     Litecoin    LTC      litecoin               912
# 12  6636     Polkadot    DOT  polkadot-new               502
# 13  4687  Binance USD   BUSD   binance-usd              6787
# 14  5994    Shiba Inu   SHIB     shiba-inu               526
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2018-10-08T00:00:00.000Z
# 5   2013-08-04T00:00:00.000Z
# 6   2017-10-01T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2019-04-28T00:00:00.000Z
# 9   2020-04-10T00:00:00.000Z
# 10  2017-09-13T00:00:00.000Z
# 11  2013-04-28T00:00:00.000Z
# 12  2020-08-19T00:00:00.000Z
# 13  2019-09-20T00:00:00.000Z
# 14  2020-08-01T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 5   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 6   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 7   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 8   [platform, enterprise-solutions, zero-knowledg...  1.000000e+10
# 9   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 10                  [media, payments, tron-ecosystem]           NaN
# 11        [mineable, pow, scrypt, medium-of-exchange]  8.400000e+07
# 12  [substrate, polkadot, binance-chain, polkadot-...           NaN
# 13  [stablecoin, asset-backed-stablecoin, binance-...           NaN
# 14      [memes, ethereum-ecosystem, doggone-doggerel]           NaN
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.938090e+07  1.938090e+07            False       NaN         1
# 1         1.202694e+08  1.202694e+08             True       NaN         2
# 2         8.291908e+10  8.609064e+10             True       NaN         3
# 3         1.558582e+08  1.558582e+08            False       NaN         4
# 4         2.942094e+10  2.942094e+10            False       NaN         5
# 5         5.187315e+10  9.998893e+10            False       NaN         6
# 6         3.486311e+10  3.581044e+10            False       NaN         7
# 7         1.394561e+11  1.394561e+11             True       NaN         8
# 8         9.279469e+09  1.000000e+10            False       NaN         9
# 9         3.960871e+08  5.483048e+08             True       NaN        10
# 10        9.033444e+10  9.033445e+10             True       NaN        11
# 11        7.297924e+07  8.400000e+07            False       NaN        12
# 12        1.186504e+09  1.315983e+09             True       NaN        13
# 13        5.499802e+09  5.499802e+09             True       NaN        14
# 14        5.895343e+14  5.895977e+14            False       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap tvl_ratio  \
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# 5                                NaN                       NaN      None
# 6                                NaN                       NaN      None
# 7                                NaN                       NaN      None
# 8                                NaN                       NaN      None
# 9                                NaN                       NaN      None
# 10                      7.165966e+10              5.597995e+09      None
# 11                               NaN                       NaN      None
# 12                               NaN                       NaN      None
# 13                               NaN                       NaN      None
# 14                               NaN                       NaN      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2023-05-22T23:52:00.000Z     26860.295891          1.106694e+10
# 1   2023-05-22T23:52:00.000Z      1818.186665          4.542421e+09
# 2   2023-05-22T23:52:00.000Z         1.000306          1.722487e+10
# 3   2023-05-22T23:52:00.000Z       309.260770          3.551214e+08
# 4   2023-05-22T23:52:00.000Z         1.000044          2.589665e+09
# 5   2023-05-22T23:52:00.000Z         0.461597          9.052699e+08
# 6   2023-05-22T23:52:00.000Z         0.367953          1.780675e+08
# 7   2023-05-22T23:52:00.000Z         0.073016          2.099416e+08
# 8   2023-05-22T23:52:00.000Z         0.872274          2.476942e+08
# 9   2023-05-22T23:52:00.000Z        19.564409          2.161522e+08
# 10  2023-05-22T23:52:00.000Z         0.078119          4.005573e+08
# 11  2023-05-22T23:52:00.000Z        90.944020          3.975936e+08
# 12  2023-05-22T23:52:00.000Z         5.315811          9.081132e+07
# 13  2023-05-22T23:52:00.000Z         1.000081          1.789174e+09
# 14  2023-05-22T23:52:00.000Z         0.000009          1.546531e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                       28.0691                    -0.073055
# 1                       34.2648                    -0.063046
# 2                       27.3423                     0.009568
# 3                       17.3465                    -0.120474
# 4                       45.7647                     0.012059
# 5                       68.7406                     0.086761
# 6                       53.0880                    -0.100934
# 7                       47.7776                    -0.065716
# 8                       28.0889                     0.009000
# 9                        2.9858                    -0.288246
# 10                      18.8271                    -0.415203
# 11                       8.9826                    -0.138265
# 12                       8.2496                     0.012608
# 13                      29.6675                     0.010725
# 14                     131.5143                     0.121439
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       0.309615                    -1.183662
# 1                       0.695398                     0.047988
# 2                       0.000287                     0.016252
# 3                       0.844175                    -1.354583
# 4                       0.010497                     0.013862
# 5                       0.753655                     8.011195
# 6                       1.982241                     0.121824
# 7                       1.136688                     1.310121
# 8                       1.714663                     1.378830
# 9                      -0.467553                    -6.856040
# 10                      3.852113                    11.229125
# 11                     -1.570943                     4.345332
# 12                      0.711319                    -0.097975
# 13                      0.025461                     0.001242
# 14                      2.911328                    -0.258239
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                      -3.413492                     -5.201236
# 1                      -2.999331                      0.089094
# 2                       0.010885                     -0.036187
# 3                      -6.907472                     -6.268399
# 4                      -0.006022                      0.142837
# 5                      -2.356760                      3.669118
# 6                      -7.090047                     -1.063433
# 7                      -9.257870                     -5.734707
# 8                     -14.950713                    -23.272590
# 9                     -10.345622                    -11.954102
# 10                     18.306382                     19.531471
# 11                      4.358908                     -2.831822
# 12                    -10.732411                    -15.963717
# 13                      0.009133                      0.015685
# 14                    -16.049536                    -19.078767
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      10.071221          5.205767e+11
# 1                       9.777863          2.186722e+11
# 2                       0.015142          8.294444e+10
# 3                      -0.601696          4.820082e+10
# 4                       0.001485          2.942223e+10
# 5                      17.889350          2.394447e+10
# 6                      -6.109727          1.282797e+10
# 7                     -14.423580          1.018253e+10
# 8                     -36.881336          8.094243e+09
# 9                     -21.417767          7.749210e+09
# 10                     12.540234          7.056854e+09
# 11                     -2.815837          6.637025e+09
# 12                    -26.617344          6.307234e+09
# 13                     -0.007516          5.500245e+09
# 14                    -32.647063          5.179911e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          46.3096                        5.640662e+11
# 1                          19.4527                        2.186722e+11
# 2                           7.3786                        8.611698e+10
# 3                           4.2879                        4.820082e+10
# 4                           2.6174                        2.942223e+10
# 5                           2.1302                        4.615966e+10
# 6                           1.1412                        1.655787e+10
# 7                           0.9058                        1.018253e+10
# 8                           0.7201                        8.722744e+09
# 9                           0.6894                        1.072726e+10
# 10                          0.6278                        7.056855e+09
# 11                          0.5904                        7.639298e+09
# 12                          0.5611                        6.995519e+09
# 13                          0.4893                        5.500245e+09
# 14                          0.4608                        5.180468e+09
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2023-05-22T23:52:00.000Z          NaN           NaN
# 1           None  2023-05-22T23:52:00.000Z          NaN           NaN
# 2           None  2023-05-22T23:52:00.000Z       1027.0      Ethereum
# 3           None  2023-05-22T23:52:00.000Z          NaN           NaN
# 4           None  2023-05-22T23:52:00.000Z       1027.0      Ethereum
# 5           None  2023-05-22T23:52:00.000Z          NaN           NaN
# 6           None  2023-05-22T23:52:00.000Z          NaN           NaN
# 7           None  2023-05-22T23:52:00.000Z          NaN           NaN
# 8           None  2023-05-22T23:52:00.000Z          NaN           NaN
# 9           None  2023-05-22T23:52:00.000Z          NaN           NaN
# 10          None  2023-05-22T23:52:00.000Z          NaN           NaN
# 11          None  2023-05-22T23:52:00.000Z          NaN           NaN
# 12          None  2023-05-22T23:52:00.000Z          NaN           NaN
# 13          None  2023-05-22T23:52:00.000Z       1839.0           BNB
# 14          None  2023-05-22T23:52:00.000Z       1027.0      Ethereum
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 5              NaN           NaN                                         NaN
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             NaN           NaN                                         NaN
# 13             BNB           bnb                                    BUSD-BD1
# 14             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
#
#                     timestamp
# 0  2023-05-22 23:53:32.562509
# 1  2023-05-22 23:53:32.562509
# 2  2023-05-22 23:53:32.562509
# 3  2023-05-22 23:53:32.562509
# 4  2023-05-22 23:53:32.562509
# 5  2023-05-22 23:53:32.562509
# 6  2023-05-22 23:53:32.562509
# 7  2023-05-22 23:53:32.562509
# 8  2023-05-22 23:53:32.562509
# 9  2023-05-22 23:53:32.562509
# 10 2023-05-22 23:53:32.562509
# 11 2023-05-22 23:53:32.562509
# 12 2023-05-22 23:53:32.562509
# 13 2023-05-22 23:53:32.562509
# 14 2023-05-22 23:53:32.562509

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '5ab21e2b-27af-45b7-932c-a6be562be5d0',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    
    df = pd.json_normalize(data['data'])
    df['timestamp'] = pd.to_datetime('now')
    df
    
    if not os.path.isfile(r'C:\Users\PC\Python Scripts\API.csv'):
        df.to_csv(r'C:\Users\PC\Python Scripts\API.csv', header='column_names')
    else:
        df.to_csv(r'C:\Users\PC\Python Scripts\API.csv', mode='a', header=False)

# %%
import os
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(86400)
exit()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_24360\386282440.py:25: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['timestamp'] = pd.to_datetime('now')
# API Runner completed
# C:\Users\PC\AppData\Local\Temp\ipykernel_24360\386282440.py:25: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['timestamp'] = pd.to_datetime('now')
# API Runner completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 8
#       6     api_runner()
#       7     print('API Runner completed')
# ----> 8     sleep(60)
#       9 exit()
#
# KeyboardInterrupt:

# %%
df72 = pd.read_csv(r'C:\Users\PC\Python Scripts\API.csv')
df72
# Out:
#     Unnamed: 0    id         name symbol          slug  num_market_pairs  \
# 0            0     1      Bitcoin    BTC       bitcoin             10216
# 1            1  1027     Ethereum    ETH      ethereum              6914
# 2            2   825       Tether   USDT        tether             53688
# 3            3  1839          BNB    BNB           bnb              1378
# 4            4  3408     USD Coin   USDC      usd-coin             12539
# 5            5    52          XRP    XRP           xrp               950
# 6            6  2010      Cardano    ADA       cardano               789
# 7            7    74     Dogecoin   DOGE      dogecoin               710
# 8            8  5426       Solana    SOL        solana               463
# 9            9  3890      Polygon  MATIC       polygon               705
# 10          10     2     Litecoin    LTC      litecoin               912
# 11          11  1958         TRON    TRX          tron               759
# 12          12  6636     Polkadot    DOT  polkadot-new               502
# 13          13  4687  Binance USD   BUSD   binance-usd              6772
# 14          14  5994    Shiba Inu   SHIB     shiba-inu               525
# 15           0     1      Bitcoin    BTC       bitcoin             10216
# 16           1  1027     Ethereum    ETH      ethereum              6914
# 17           2   825       Tether   USDT        tether             53688
# 18           3  1839          BNB    BNB           bnb              1378
# 19           4  3408     USD Coin   USDC      usd-coin             12539
# 20           5    52          XRP    XRP           xrp               950
# 21           6  2010      Cardano    ADA       cardano               789
# 22           7    74     Dogecoin   DOGE      dogecoin               710
# 23           8  5426       Solana    SOL        solana               463
# 24           9  3890      Polygon  MATIC       polygon               705
# 25          10     2     Litecoin    LTC      litecoin               912
# 26          11  1958         TRON    TRX          tron               759
# 27          12  6636     Polkadot    DOT  polkadot-new               502
# 28          13  4687  Binance USD   BUSD   binance-usd              6772
# 29          14  5994    Shiba Inu   SHIB     shiba-inu               525
# 30           0     1      Bitcoin    BTC       bitcoin             10216
# 31           1  1027     Ethereum    ETH      ethereum              6914
# 32           2   825       Tether   USDT        tether             53688
# 33           3  1839          BNB    BNB           bnb              1378
# 34           4  3408     USD Coin   USDC      usd-coin             12539
# 35           5    52          XRP    XRP           xrp               950
# 36           6  2010      Cardano    ADA       cardano               789
# 37           7    74     Dogecoin   DOGE      dogecoin               710
# 38           8  5426       Solana    SOL        solana               463
# 39           9  3890      Polygon  MATIC       polygon               705
# 40          10     2     Litecoin    LTC      litecoin               912
# 41          11  1958         TRON    TRX          tron               759
# 42          12  6636     Polkadot    DOT  polkadot-new               502
# 43          13  4687  Binance USD   BUSD   binance-usd              6772
# 44          14  5994    Shiba Inu   SHIB     shiba-inu               525
# 45           0     1      Bitcoin    BTC       bitcoin             10221
# 46           1  1027     Ethereum    ETH      ethereum              6933
# 47           2   825       Tether   USDT        tether             53878
# 48           3  1839          BNB    BNB           bnb              1387
# 49           4  3408     USD Coin   USDC      usd-coin             12582
# 50           5    52          XRP    XRP           xrp               951
# 51           6  2010      Cardano    ADA       cardano               790
# 52           7    74     Dogecoin   DOGE      dogecoin               711
# 53           8  3890      Polygon  MATIC       polygon               709
# 54           9  5426       Solana    SOL        solana               463
# 55          10  1958         TRON    TRX          tron               759
# 56          11     2     Litecoin    LTC      litecoin               912
# 57          12  6636     Polkadot    DOT  polkadot-new               502
# 58          13  4687  Binance USD   BUSD   binance-usd              6787
# 59          14  5994    Shiba Inu   SHIB     shiba-inu               526
# 60           0     1      Bitcoin    BTC       bitcoin             10221
# 61           1  1027     Ethereum    ETH      ethereum              6933
# 62           2   825       Tether   USDT        tether             53878
# 63           3  1839          BNB    BNB           bnb              1387
# 64           4  3408     USD Coin   USDC      usd-coin             12582
# 65           5    52          XRP    XRP           xrp               951
# 66           6  2010      Cardano    ADA       cardano               790
# 67           7    74     Dogecoin   DOGE      dogecoin               711
# 68           8  3890      Polygon  MATIC       polygon               709
# 69           9  5426       Solana    SOL        solana               463
# 70          10  1958         TRON    TRX          tron               759
# 71          11     2     Litecoin    LTC      litecoin               912
# 72          12  6636     Polkadot    DOT  polkadot-new               502
# 73          13  4687  Binance USD   BUSD   binance-usd              6787
# 74          14  5994    Shiba Inu   SHIB     shiba-inu               526
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2018-10-08T00:00:00.000Z
# 5   2013-08-04T00:00:00.000Z
# 6   2017-10-01T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2020-04-10T00:00:00.000Z
# 9   2019-04-28T00:00:00.000Z
# 10  2013-04-28T00:00:00.000Z
# 11  2017-09-13T00:00:00.000Z
# 12  2020-08-19T00:00:00.000Z
# 13  2019-09-20T00:00:00.000Z
# 14  2020-08-01T00:00:00.000Z
# 15  2010-07-13T00:00:00.000Z
# 16  2015-08-07T00:00:00.000Z
# 17  2015-02-25T00:00:00.000Z
# 18  2017-07-25T00:00:00.000Z
# 19  2018-10-08T00:00:00.000Z
# 20  2013-08-04T00:00:00.000Z
# 21  2017-10-01T00:00:00.000Z
# 22  2013-12-15T00:00:00.000Z
# 23  2020-04-10T00:00:00.000Z
# 24  2019-04-28T00:00:00.000Z
# 25  2013-04-28T00:00:00.000Z
# 26  2017-09-13T00:00:00.000Z
# 27  2020-08-19T00:00:00.000Z
# 28  2019-09-20T00:00:00.000Z
# 29  2020-08-01T00:00:00.000Z
# 30  2010-07-13T00:00:00.000Z
# 31  2015-08-07T00:00:00.000Z
# 32  2015-02-25T00:00:00.000Z
# 33  2017-07-25T00:00:00.000Z
# 34  2018-10-08T00:00:00.000Z
# 35  2013-08-04T00:00:00.000Z
# 36  2017-10-01T00:00:00.000Z
# 37  2013-12-15T00:00:00.000Z
# 38  2020-04-10T00:00:00.000Z
# 39  2019-04-28T00:00:00.000Z
# 40  2013-04-28T00:00:00.000Z
# 41  2017-09-13T00:00:00.000Z
# 42  2020-08-19T00:00:00.000Z
# 43  2019-09-20T00:00:00.000Z
# 44  2020-08-01T00:00:00.000Z
# 45  2010-07-13T00:00:00.000Z
# 46  2015-08-07T00:00:00.000Z
# 47  2015-02-25T00:00:00.000Z
# 48  2017-07-25T00:00:00.000Z
# 49  2018-10-08T00:00:00.000Z
# 50  2013-08-04T00:00:00.000Z
# 51  2017-10-01T00:00:00.000Z
# 52  2013-12-15T00:00:00.000Z
# 53  2019-04-28T00:00:00.000Z
# 54  2020-04-10T00:00:00.000Z
# 55  2017-09-13T00:00:00.000Z
# 56  2013-04-28T00:00:00.000Z
# 57  2020-08-19T00:00:00.000Z
# 58  2019-09-20T00:00:00.000Z
# 59  2020-08-01T00:00:00.000Z
# 60  2010-07-13T00:00:00.000Z
# 61  2015-08-07T00:00:00.000Z
# 62  2015-02-25T00:00:00.000Z
# 63  2017-07-25T00:00:00.000Z
# 64  2018-10-08T00:00:00.000Z
# 65  2013-08-04T00:00:00.000Z
# 66  2017-10-01T00:00:00.000Z
# 67  2013-12-15T00:00:00.000Z
# 68  2019-04-28T00:00:00.000Z
# 69  2020-04-10T00:00:00.000Z
# 70  2017-09-13T00:00:00.000Z
# 71  2013-04-28T00:00:00.000Z
# 72  2020-08-19T00:00:00.000Z
# 73  2019-09-20T00:00:00.000Z
# 74  2020-08-01T00:00:00.000Z
#
#                                                  tags         max_supply  \
# 0   ['mineable', 'pow', 'sha-256', 'store-of-value...     21000000.00000
# 1   ['pos', 'smart-contracts', 'ethereum-ecosystem...                NaN
# 2   ['payments', 'stablecoin', 'asset-backed-stabl...                NaN
# 3   ['marketplace', 'centralized-exchange', 'payme...                NaN
# 4   ['medium-of-exchange', 'stablecoin', 'asset-ba...                NaN
# 5   ['medium-of-exchange', 'enterprise-solutions',... 100000000000.00000
# 6   ['dpos', 'pos', 'platform', 'research', 'smart...  45000000000.00000
# 7   ['mineable', 'pow', 'scrypt', 'medium-of-excha...                NaN
# 8   ['pos', 'platform', 'solana-ecosystem', 'cms-h...                NaN
# 9   ['platform', 'enterprise-solutions', 'zero-kno...  10000000000.00000
# 10  ['mineable', 'pow', 'scrypt', 'medium-of-excha...     84000000.00000
# 11            ['media', 'payments', 'tron-ecosystem']                NaN
# 12  ['substrate', 'polkadot', 'binance-chain', 'po...                NaN
# 13  ['stablecoin', 'asset-backed-stablecoin', 'bin...                NaN
# 14  ['memes', 'ethereum-ecosystem', 'doggone-dogge...                NaN
# 15  ['mineable', 'pow', 'sha-256', 'store-of-value...     21000000.00000
# 16  ['pos', 'smart-contracts', 'ethereum-ecosystem...                NaN
# 17  ['payments', 'stablecoin', 'asset-backed-stabl...                NaN
# 18  ['marketplace', 'centralized-exchange', 'payme...                NaN
# 19  ['medium-of-exchange', 'stablecoin', 'asset-ba...                NaN
# 20  ['medium-of-exchange', 'enterprise-solutions',... 100000000000.00000
# 21  ['dpos', 'pos', 'platform', 'research', 'smart...  45000000000.00000
# 22  ['mineable', 'pow', 'scrypt', 'medium-of-excha...                NaN
# 23  ['pos', 'platform', 'solana-ecosystem', 'cms-h...                NaN
# 24  ['platform', 'enterprise-solutions', 'zero-kno...  10000000000.00000
# 25  ['mineable', 'pow', 'scrypt', 'medium-of-excha...     84000000.00000
# 26            ['media', 'payments', 'tron-ecosystem']                NaN
# 27  ['substrate', 'polkadot', 'binance-chain', 'po...                NaN
# 28  ['stablecoin', 'asset-backed-stablecoin', 'bin...                NaN
# 29  ['memes', 'ethereum-ecosystem', 'doggone-dogge...                NaN
# 30  ['mineable', 'pow', 'sha-256', 'store-of-value...     21000000.00000
# 31  ['pos', 'smart-contracts', 'ethereum-ecosystem...                NaN
# 32  ['payments', 'stablecoin', 'asset-backed-stabl...                NaN
# 33  ['marketplace', 'centralized-exchange', 'payme...                NaN
# 34  ['medium-of-exchange', 'stablecoin', 'asset-ba...                NaN
# 35  ['medium-of-exchange', 'enterprise-solutions',... 100000000000.00000
# 36  ['dpos', 'pos', 'platform', 'research', 'smart...  45000000000.00000
# 37  ['mineable', 'pow', 'scrypt', 'medium-of-excha...                NaN
# 38  ['pos', 'platform', 'solana-ecosystem', 'cms-h...                NaN
# 39  ['platform', 'enterprise-solutions', 'zero-kno...  10000000000.00000
# 40  ['mineable', 'pow', 'scrypt', 'medium-of-excha...     84000000.00000
# 41            ['media', 'payments', 'tron-ecosystem']                NaN
# 42  ['substrate', 'polkadot', 'binance-chain', 'po...                NaN
# 43  ['stablecoin', 'asset-backed-stablecoin', 'bin...                NaN
# 44  ['memes', 'ethereum-ecosystem', 'doggone-dogge...                NaN
# 45  ['mineable', 'pow', 'sha-256', 'store-of-value...     21000000.00000
# 46  ['pos', 'smart-contracts', 'ethereum-ecosystem...                NaN
# 47  ['payments', 'stablecoin', 'asset-backed-stabl...                NaN
# 48  ['marketplace', 'centralized-exchange', 'payme...                NaN
# 49  ['medium-of-exchange', 'stablecoin', 'asset-ba...                NaN
# 50  ['medium-of-exchange', 'enterprise-solutions',... 100000000000.00000
# 51  ['dpos', 'pos', 'platform', 'research', 'smart...  45000000000.00000
# 52  ['mineable', 'pow', 'scrypt', 'medium-of-excha...                NaN
# 53  ['platform', 'enterprise-solutions', 'zero-kno...  10000000000.00000
# 54  ['pos', 'platform', 'solana-ecosystem', 'cms-h...                NaN
# 55            ['media', 'payments', 'tron-ecosystem']                NaN
# 56  ['mineable', 'pow', 'scrypt', 'medium-of-excha...     84000000.00000
# 57  ['substrate', 'polkadot', 'binance-chain', 'po...                NaN
# 58  ['stablecoin', 'asset-backed-stablecoin', 'bin...                NaN
# 59  ['memes', 'ethereum-ecosystem', 'doggone-dogge...                NaN
# 60  ['mineable', 'pow', 'sha-256', 'store-of-value...     21000000.00000
# 61  ['pos', 'smart-contracts', 'ethereum-ecosystem...                NaN
# 62  ['payments', 'stablecoin', 'asset-backed-stabl...                NaN
# 63  ['marketplace', 'centralized-exchange', 'payme...                NaN
# 64  ['medium-of-exchange', 'stablecoin', 'asset-ba...                NaN
# 65  ['medium-of-exchange', 'enterprise-solutions',... 100000000000.00000
# 66  ['dpos', 'pos', 'platform', 'research', 'smart...  45000000000.00000
# 67  ['mineable', 'pow', 'scrypt', 'medium-of-excha...                NaN
# 68  ['platform', 'enterprise-solutions', 'zero-kno...  10000000000.00000
# 69  ['pos', 'platform', 'solana-ecosystem', 'cms-h...                NaN
# 70            ['media', 'payments', 'tron-ecosystem']                NaN
# 71  ['mineable', 'pow', 'scrypt', 'medium-of-excha...     84000000.00000
# 72  ['substrate', 'polkadot', 'binance-chain', 'po...                NaN
# 73  ['stablecoin', 'asset-backed-stablecoin', 'bin...                NaN
# 74  ['memes', 'ethereum-ecosystem', 'doggone-dogge...                NaN
#
#       circulating_supply          total_supply  infinite_supply  platform  \
# 0         19377237.00000        19377237.00000            False       NaN
# 1        120279329.57349       120279329.57349             True       NaN
# 2      82845432957.31229     86090638895.06883             True       NaN
# 3        155858945.69106       155858945.69106            False       NaN
# 4      29616186210.44225     29616186210.44225            False       NaN
# 5      51837820505.00000     99988965239.00000            False       NaN
# 6      34856444888.96500     35793946862.56700            False       NaN
# 7     139400696383.70526    139400696383.70526             True       NaN
# 8        395775048.92265       547941695.90471             True       NaN
# 9       9279469069.28493     10000000000.00000            False       NaN
# 10        72949801.80932        84000000.00000            False       NaN
# 11     90380532160.06000     90380560300.18384             True       NaN
# 12      1185171698.69333      1314650575.99851             True       NaN
# 13      5544850540.05338      5544850540.05338             True       NaN
# 14 589534333568906.25000 589597746628688.62500            False       NaN
# 15        19377237.00000        19377237.00000            False       NaN
# 16       120279329.57349       120279329.57349             True       NaN
# 17     82845432957.31229     86090638895.06883             True       NaN
# 18       155858945.69106       155858945.69106            False       NaN
# 19     29616186210.44225     29616186210.44225            False       NaN
# 20     51837820505.00000     99988965239.00000            False       NaN
# 21     34856444888.96500     35793946862.56700            False       NaN
# 22    139400696383.70526    139400696383.70526             True       NaN
# 23       395775048.92265       547941695.90471             True       NaN
# 24      9279469069.28493     10000000000.00000            False       NaN
# 25        72949801.80932        84000000.00000            False       NaN
# 26     90380532160.06000     90380560300.18384             True       NaN
# 27      1185171698.69333      1314650575.99851             True       NaN
# 28      5544850540.05338      5544850540.05338             True       NaN
# 29 589534333568906.25000 589597746628688.62500            False       NaN
# 30        19377237.00000        19377237.00000            False       NaN
# 31       120279329.57349       120279329.57349             True       NaN
# 32     82845432957.31229     86090638895.06883             True       NaN
# 33       155858945.69106       155858945.69106            False       NaN
# 34     29616186210.44225     29616186210.44225            False       NaN
# 35     51837820505.00000     99988965239.00000            False       NaN
# 36     34856444888.96500     35793946862.56700            False       NaN
# 37    139400696383.70526    139400696383.70526             True       NaN
# 38       395775048.92265       547941695.90471             True       NaN
# 39      9279469069.28493     10000000000.00000            False       NaN
# 40        72949801.80932        84000000.00000            False       NaN
# 41     90380532160.06000     90380560300.18384             True       NaN
# 42      1185171698.69333      1314650575.99851             True       NaN
# 43      5544850540.05338      5544850540.05338             True       NaN
# 44 589534333568906.25000 589597746628688.62500            False       NaN
# 45        19380900.00000        19380900.00000            False       NaN
# 46       120269409.46943       120269409.46943             True       NaN
# 47     82919078535.20427     86090638895.05328             True       NaN
# 48       155858168.20289       155858168.20289            False       NaN
# 49     29420939250.75391     29420939250.75391            False       NaN
# 50     51873152538.00000     99988934739.00000            False       NaN
# 51     34863111584.60900     35810438256.57800            False       NaN
# 52    139456066383.70523    139456066383.70523             True       NaN
# 53      9279469069.28493     10000000000.00000            False       NaN
# 54       396087084.31639       548304788.49960             True       NaN
# 55     90334442435.67618     90334453637.35884             True       NaN
# 56        72979239.30932        84000000.00000            False       NaN
# 57      1186504407.85935      1315983285.16453             True       NaN
# 58      5499801594.05338      5499801594.05338             True       NaN
# 59 589534333568906.25000 589597746628688.62500            False       NaN
# 60        19380900.00000        19380900.00000            False       NaN
# 61       120269409.46943       120269409.46943             True       NaN
# 62     82919078535.20427     86090638895.05328             True       NaN
# 63       155858168.20289       155858168.20289            False       NaN
# 64     29420939250.75391     29420939250.75391            False       NaN
# 65     51873152538.00000     99988934739.00000            False       NaN
# 66     34863111584.60900     35810438256.57800            False       NaN
# 67    139456066383.70523    139456066383.70523             True       NaN
# 68      9279469069.28493     10000000000.00000            False       NaN
# 69       396087084.31639       548304788.49960             True       NaN
# 70     90334442435.67618     90334453637.35884             True       NaN
# 71        72979239.30932        84000000.00000            False       NaN
# 72      1186504407.85935      1315983285.16453             True       NaN
# 73      5499801594.05338      5499801594.05338             True       NaN
# 74 589534333568906.25000 589597746628688.62500            False       NaN
#
#     cmc_rank  self_reported_circulating_supply  self_reported_market_cap  \
# 0          1                               NaN                       NaN
# 1          2                               NaN                       NaN
# 2          3                               NaN                       NaN
# 3          4                               NaN                       NaN
# 4          5                               NaN                       NaN
# 5          6                               NaN                       NaN
# 6          7                               NaN                       NaN
# 7          8                               NaN                       NaN
# 8          9                               NaN                       NaN
# 9         10                               NaN                       NaN
# 10        11                               NaN                       NaN
# 11        12                 71659659264.00000          5047371018.42290
# 12        13                               NaN                       NaN
# 13        14                               NaN                       NaN
# 14        15                               NaN                       NaN
# 15         1                               NaN                       NaN
# 16         2                               NaN                       NaN
# 17         3                               NaN                       NaN
# 18         4                               NaN                       NaN
# 19         5                               NaN                       NaN
# 20         6                               NaN                       NaN
# 21         7                               NaN                       NaN
# 22         8                               NaN                       NaN
# 23         9                               NaN                       NaN
# 24        10                               NaN                       NaN
# 25        11                               NaN                       NaN
# 26        12                 71659659264.00000          5047690589.69701
# 27        13                               NaN                       NaN
# 28        14                               NaN                       NaN
# 29        15                               NaN                       NaN
# 30         1                               NaN                       NaN
# 31         2                               NaN                       NaN
# 32         3                               NaN                       NaN
# 33         4                               NaN                       NaN
# 34         5                               NaN                       NaN
# 35         6                               NaN                       NaN
# 36         7                               NaN                       NaN
# 37         8                               NaN                       NaN
# 38         9                               NaN                       NaN
# 39        10                               NaN                       NaN
# 40        11                               NaN                       NaN
# 41        12                 71659659264.00000          5048391938.23868
# 42        13                               NaN                       NaN
# 43        14                               NaN                       NaN
# 44        15                               NaN                       NaN
# 45         1                               NaN                       NaN
# 46         2                               NaN                       NaN
# 47         3                               NaN                       NaN
# 48         4                               NaN                       NaN
# 49         5                               NaN                       NaN
# 50         6                               NaN                       NaN
# 51         7                               NaN                       NaN
# 52         8                               NaN                       NaN
# 53         9                               NaN                       NaN
# 54        10                               NaN                       NaN
# 55        11                 71659659264.00000          5597994790.01203
# 56        12                               NaN                       NaN
# 57        13                               NaN                       NaN
# 58        14                               NaN                       NaN
# 59        15                               NaN                       NaN
# 60         1                               NaN                       NaN
# 61         2                               NaN                       NaN
# 62         3                               NaN                       NaN
# 63         4                               NaN                       NaN
# 64         5                               NaN                       NaN
# 65         6                               NaN                       NaN
# 66         7                               NaN                       NaN
# 67         8                               NaN                       NaN
# 68         9                               NaN                       NaN
# 69        10                               NaN                       NaN
# 70        11                 71659659264.00000          5598305381.31073
# 71        12                               NaN                       NaN
# 72        13                               NaN                       NaN
# 73        14                               NaN                       NaN
# 74        15                               NaN                       NaN
#
#     tvl_ratio              last_updated  quote.USD.price  \
# 0         NaN  2023-05-18T21:29:00.000Z      26806.88052
# 1         NaN  2023-05-18T21:29:00.000Z       1800.67016
# 2         NaN  2023-05-18T21:29:00.000Z          0.99991
# 3         NaN  2023-05-18T21:29:00.000Z        308.77317
# 4         NaN  2023-05-18T21:29:00.000Z          0.99998
# 5         NaN  2023-05-18T21:29:00.000Z          0.46339
# 6         NaN  2023-05-18T21:29:00.000Z          0.37259
# 7         NaN  2023-05-18T21:29:00.000Z          0.07276
# 8         NaN  2023-05-18T21:29:00.000Z         20.39764
# 9         NaN  2023-05-18T21:29:00.000Z          0.85878
# 10        NaN  2023-05-18T21:29:00.000Z         91.10095
# 11        NaN  2023-05-18T21:29:00.000Z          0.07044
# 12        NaN  2023-05-18T21:29:00.000Z          5.32401
# 13        NaN  2023-05-18T21:29:00.000Z          0.99987
# 14        NaN  2023-05-18T21:29:00.000Z          0.00001
# 15        NaN  2023-05-18T21:30:00.000Z      26849.35726
# 16        NaN  2023-05-18T21:30:00.000Z       1802.19886
# 17        NaN  2023-05-18T21:30:00.000Z          1.00004
# 18        NaN  2023-05-18T21:30:00.000Z        308.80392
# 19        NaN  2023-05-18T21:30:00.000Z          1.00001
# 20        NaN  2023-05-18T21:30:00.000Z          0.46345
# 21        NaN  2023-05-18T21:30:00.000Z          0.37270
# 22        NaN  2023-05-18T21:30:00.000Z          0.07277
# 23        NaN  2023-05-18T21:30:00.000Z         20.40799
# 24        NaN  2023-05-18T21:30:00.000Z          0.85892
# 25        NaN  2023-05-18T21:30:00.000Z         91.15876
# 26        NaN  2023-05-18T21:30:00.000Z          0.07044
# 27        NaN  2023-05-18T21:30:00.000Z          5.32559
# 28        NaN  2023-05-18T21:30:00.000Z          0.99986
# 29        NaN  2023-05-18T21:30:00.000Z          0.00001
# 30        NaN  2023-05-18T21:31:00.000Z      26830.35474
# 31        NaN  2023-05-18T21:31:00.000Z       1801.50257
# 32        NaN  2023-05-18T21:31:00.000Z          1.00014
# 33        NaN  2023-05-18T21:31:00.000Z        308.85429
# 34        NaN  2023-05-18T21:31:00.000Z          0.99972
# 35        NaN  2023-05-18T21:31:00.000Z          0.46347
# 36        NaN  2023-05-18T21:31:00.000Z          0.37279
# 37        NaN  2023-05-18T21:31:00.000Z          0.07281
# 38        NaN  2023-05-18T21:31:00.000Z         20.41870
# 39        NaN  2023-05-18T21:31:00.000Z          0.85917
# 40        NaN  2023-05-18T21:31:00.000Z         91.30855
# 41        NaN  2023-05-18T21:31:00.000Z          0.07045
# 42        NaN  2023-05-18T21:31:00.000Z          5.32697
# 43        NaN  2023-05-18T21:31:00.000Z          0.99971
# 44        NaN  2023-05-18T21:31:00.000Z          0.00001
# 45        NaN  2023-05-22T23:52:00.000Z      26860.29589
# 46        NaN  2023-05-22T23:52:00.000Z       1818.18667
# 47        NaN  2023-05-22T23:52:00.000Z          1.00031
# 48        NaN  2023-05-22T23:52:00.000Z        309.26077
# 49        NaN  2023-05-22T23:52:00.000Z          1.00004
# 50        NaN  2023-05-22T23:52:00.000Z          0.46160
# 51        NaN  2023-05-22T23:52:00.000Z          0.36795
# 52        NaN  2023-05-22T23:52:00.000Z          0.07302
# 53        NaN  2023-05-22T23:52:00.000Z          0.87227
# 54        NaN  2023-05-22T23:52:00.000Z         19.56441
# 55        NaN  2023-05-22T23:52:00.000Z          0.07812
# 56        NaN  2023-05-22T23:52:00.000Z         90.94402
# 57        NaN  2023-05-22T23:52:00.000Z          5.31581
# 58        NaN  2023-05-22T23:52:00.000Z          1.00008
# 59        NaN  2023-05-22T23:52:00.000Z          0.00001
# 60        NaN  2023-05-22T23:53:00.000Z      26861.47332
# 61        NaN  2023-05-22T23:53:00.000Z       1818.29939
# 62        NaN  2023-05-22T23:53:00.000Z          1.00028
# 63        NaN  2023-05-22T23:53:00.000Z        309.25770
# 64        NaN  2023-05-22T23:53:00.000Z          1.00004
# 65        NaN  2023-05-22T23:53:00.000Z          0.46159
# 66        NaN  2023-05-22T23:53:00.000Z          0.36795
# 67        NaN  2023-05-22T23:53:00.000Z          0.07302
# 68        NaN  2023-05-22T23:53:00.000Z          0.87224
# 69        NaN  2023-05-22T23:53:00.000Z         19.56075
# 70        NaN  2023-05-22T23:53:00.000Z          0.07812
# 71        NaN  2023-05-22T23:53:00.000Z         90.94692
# 72        NaN  2023-05-22T23:53:00.000Z          5.31558
# 73        NaN  2023-05-22T23:53:00.000Z          1.00007
# 74        NaN  2023-05-22T23:53:00.000Z          0.00001
#
#     quote.USD.volume_24h  quote.USD.volume_change_24h  \
# 0      15028788998.04476                      0.85080
# 1       5441992291.47934                    -13.11620
# 2      22130859354.18241                     -8.01080
# 3        379621067.69999                    -12.03270
# 4       2893852380.08550                     -7.25690
# 5       1321399710.48247                    -22.35720
# 6        194578950.68674                    -12.82640
# 7        281310736.15546                    -15.29820
# 8        299129750.33514                     10.25160
# 9        326908306.18623                    -26.34990
# 10       576505930.43373                    -45.07020
# 11       187328255.84634                      3.33390
# 12       114099437.18167                      0.14000
# 13      1956200171.20841                     -9.50190
# 14        99408284.65418                     -8.07990
# 15     15040821480.92870                      0.91600
# 16      5443130046.66297                    -13.09920
# 17     22135566166.69541                     -7.99820
# 18       379798649.63751                    -12.01340
# 19      2893796567.93032                     -7.24120
# 20      1321477315.61247                    -22.35280
# 21       194629928.50152                    -12.83760
# 22       281335922.72812                    -15.25220
# 23       299367162.63814                     10.36740
# 24       327005855.09419                    -26.33250
# 25       576973019.90819                    -45.03320
# 26       187341284.00502                      3.27980
# 27       114107716.03948                      0.12020
# 28      1958015601.70344                     -9.42660
# 29        99449300.30509                     -8.03870
# 30     15064977933.73525                      1.07810
# 31      5457803779.84286                    -12.86500
# 32     22160245181.49548                     -7.89560
# 33       379057614.83858                    -12.18510
# 34      2899501641.00414                     -7.05830
# 35      1321933346.67359                    -22.32600
# 36       194807023.22090                    -12.75830
# 37       281494049.72996                    -15.20460
# 38       299659501.78953                     10.47510
# 39       327435156.22522                    -26.23580
# 40       575798586.98270                    -45.14510
# 41       187390574.69938                      3.30700
# 42       114175568.56592                      0.17970
# 43      1958962857.14892                     -9.38280
# 44        99588973.31873                     -7.90950
# 45     11066935108.87249                     28.06910
# 46      4542420760.67064                     34.26480
# 47     17224865902.65665                     27.34230
# 48       355121395.53616                     17.34650
# 49      2589664657.66979                     45.76470
# 50       905269878.11983                     68.74060
# 51       178067500.38996                     53.08800
# 52       209941572.80189                     47.77760
# 53       247694242.14786                     28.08890
# 54       216152216.33519                      2.98580
# 55       400557258.29350                     18.82710
# 56       397593590.96521                      8.98260
# 57        90811321.64459                      8.24960
# 58      1789174079.75103                     29.66750
# 59       154653145.47166                    131.51430
# 60     11065288535.10376                     28.05010
# 61      4541630296.77448                     34.24150
# 62     17222675171.24683                     27.32610
# 63       355072240.41954                     17.33030
# 64      2589335523.53087                     45.74620
# 65       905075636.89414                     68.70440
# 66       178052051.95489                     53.07470
# 67       209906553.30820                     47.75300
# 68       247685678.69089                     28.08450
# 69       216497190.47518                      3.15020
# 70       400652019.92939                     18.85520
# 71       397578877.30467                      8.97850
# 72        90779640.31612                      8.21190
# 73      1789028049.93932                     29.65700
# 74       154658994.14813                    131.52300
#
#     quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# 0                       0.28103                      -2.31597
# 1                       0.24734                      -1.49180
# 2                      -0.01600                      -0.02159
# 3                       0.26320                      -1.71625
# 4                       0.00527                      -0.00173
# 5                       1.34282                       3.67176
# 6                       0.48834                      -0.89333
# 7                       0.44601                      -3.26545
# 8                       0.31136                      -3.15868
# 9                       0.57766                      -3.75482
# 10                      0.88966                      -3.40566
# 11                      0.23408                      -0.96218
# 12                      0.44444                      -1.60003
# 13                     -0.00740                      -0.03236
# 14                      0.35782                      -1.92237
# 15                      0.41863                      -2.16444
# 16                      0.31914                      -1.41139
# 17                     -0.01025                      -0.02285
# 18                      0.27263                      -1.71766
# 19                     -0.00243                      -0.00894
# 20                      1.33675                       3.67031
# 21                      0.51552                      -0.87276
# 22                      0.46468                      -3.26194
# 23                      0.36723                      -3.11642
# 24                      0.59154                      -3.74144
# 25                      0.95338                      -3.36120
# 26                      0.24250                      -0.94186
# 27                      0.47481                      -1.59080
# 28                     -0.00750                      -0.03727
# 29                      0.37219                      -1.91829
# 30                      0.34361                      -2.21732
# 31                      0.25141                      -1.42782
# 32                      0.01278                       0.00090
# 33                      0.26728                      -1.69967
# 34                     -0.01898                      -0.03083
# 35                      1.24687                       3.62506
# 36                      0.52237                      -0.86959
# 37                      0.52370                      -3.22132
# 38                      0.41605                      -3.07533
# 39                      0.58718                      -3.71150
# 40                      1.08990                      -3.25841
# 41                      0.23609                      -0.87425
# 42                      0.45483                      -1.57299
# 43                     -0.03090                      -0.05035
# 44                      0.45027                      -1.86164
# 45                     -0.07306                       0.30961
# 46                     -0.06305                       0.69540
# 47                      0.00957                       0.00029
# 48                     -0.12047                       0.84417
# 49                      0.01206                       0.01050
# 50                      0.08676                       0.75365
# 51                     -0.10093                       1.98224
# 52                     -0.06572                       1.13669
# 53                      0.00900                       1.71466
# 54                     -0.28825                      -0.46755
# 55                     -0.41520                       3.85211
# 56                     -0.13826                      -1.57094
# 57                      0.01261                       0.71132
# 58                      0.01073                       0.02546
# 59                      0.12144                       2.91133
# 60                     -0.07406                       0.38359
# 61                     -0.06606                       0.77458
# 62                      0.00042                       0.00724
# 63                     -0.12146                       0.87049
# 64                      0.00188                       0.01472
# 65                      0.08548                       0.75239
# 66                     -0.10103                       1.99555
# 67                     -0.06505                       1.15090
# 68                      0.00548                       1.72971
# 69                     -0.30624                      -0.44742
# 70                     -0.41186                       3.86754
# 71                     -0.13486                      -1.55648
# 72                      0.00854                       0.71942
# 73                      0.01355                       0.02433
# 74                      0.12475                       2.91830
#
#     quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# 0                      -0.79374                     -11.68949
# 1                       0.26696                     -13.93135
# 2                      -0.05251                      -0.03997
# 3                       0.53065                      -9.83146
# 4                       0.00353                      -0.00180
# 5                      10.37759                     -11.29452
# 6                       3.93329                     -15.56016
# 7                       2.57341                     -21.81621
# 8                       1.28696                     -17.80127
# 9                       1.84324                     -26.38020
# 10                     13.64992                     -10.00763
# 11                      4.38513                       6.00427
# 12                      0.71448                     -22.72372
# 13                     -0.06886                      -0.02375
# 14                     -0.19295                     -25.20062
# 15                     -0.62803                     -11.54522
# 16                      0.35815                     -13.85340
# 17                     -0.03104                      -0.02533
# 18                      0.54753                      -9.82346
# 19                      0.01591                       0.00308
# 20                     10.39472                     -11.29241
# 21                      3.97103                     -15.53877
# 22                      2.59487                     -21.80392
# 23                      1.33805                     -17.75070
# 24                      1.87439                     -26.37167
# 25                     13.73466                      -9.95248
# 26                      4.38939                       6.01049
# 27                      0.75426                     -22.70263
# 28                     -0.04380                      -0.02567
# 29                     -0.16841                     -25.19128
# 30                     -0.69506                     -11.60659
# 31                      0.32036                     -13.85667
# 32                     -0.02681                      -0.00608
# 33                      0.55879                      -9.79570
# 34                     -0.01721                      -0.02601
# 35                     10.36022                     -11.27395
# 36                      3.98010                     -15.54911
# 37                      2.62452                     -21.78103
# 38                      1.36028                     -17.74560
# 39                      1.93989                     -26.36937
# 40                     13.95576                      -9.82010
# 41                      4.39169                       6.02011
# 42                      0.76738                     -22.71065
# 43                     -0.03261                      -0.03943
# 44                     -0.11774                     -25.15006
# 45                     -1.18366                      -3.41349
# 46                      0.04799                      -2.99933
# 47                      0.01625                       0.01088
# 48                     -1.35458                      -6.90747
# 49                      0.01386                      -0.00602
# 50                      8.01120                      -2.35676
# 51                      0.12182                      -7.09005
# 52                      1.31012                      -9.25787
# 53                      1.37883                     -14.95071
# 54                     -6.85604                     -10.34562
# 55                     11.22912                      18.30638
# 56                      4.34533                       4.35891
# 57                     -0.09798                     -10.73241
# 58                      0.00124                       0.00913
# 59                     -0.25824                     -16.04954
# 60                     -1.23477                      -3.41061
# 61                      0.01458                      -2.99995
# 62                     -0.00517                       0.00387
# 63                     -1.35923                      -6.90445
# 64                     -0.00143                      -0.00841
# 65                      8.00380                      -2.35462
# 66                      0.12268                      -7.09123
# 67                      1.32000                      -9.24916
# 68                      1.37163                     -14.95408
# 69                     -6.87745                     -10.36284
# 70                     11.23671                      18.31583
# 71                      4.35185                       4.36772
# 72                     -0.09588                     -10.72570
# 73                      0.01091                       0.00973
# 74                     -0.26114                     -16.04656
#
#     quote.USD.percent_change_60d  quote.USD.percent_change_90d  \
# 0                       -4.88439                       8.33588
# 1                       -0.58106                       5.39940
# 2                       -0.33015                      -0.02170
# 3                       -8.93777                      -2.03127
# 4                       -0.02123                      -0.00510
# 5                       18.60753                      16.26278
# 6                        7.07535                      -8.50243
# 7                       -3.66058                     -17.64584
# 8                       -7.60507                     -13.13913
# 9                      -27.80573                     -43.43613
# 10                       7.33037                      -9.99257
# 11                       5.45152                      -1.39235
# 12                     -18.14276                     -27.46848
# 13                      -0.01193                      -0.02772
# 14                     -21.51444                     -35.04775
# 15                      -4.76347                       8.54963
# 16                      -0.52660                       5.51526
# 17                      -0.31885                      -0.00789
# 18                      -8.94066                      -2.01474
# 19                      -0.01372                       0.00325
# 20                      18.59496                      16.28426
# 21                       7.10083                      -8.47014
# 22                      -3.65846                     -17.63996
# 23                      -7.57931                     -13.08280
# 24                     -27.80278                     -43.41731
# 25                       7.38430                      -9.92148
# 26                       5.44402                      -1.38307
# 27                     -18.13053                     -27.43080
# 28                      -0.00695                      -0.01693
# 29                     -21.51533                     -35.05481
# 30                      -4.83329                       8.58591
# 31                      -0.55675                       5.49513
# 32                      -0.29782                       0.00102
# 33                      -8.98329                      -2.00169
# 34                      -0.01506                      -0.02925
# 35                      18.49905                      16.31233
# 36                       7.11965                      -8.42476
# 37                      -3.62822                     -17.63839
# 38                      -7.60520                     -12.98077
# 39                     -27.78514                     -43.38865
# 40                       7.44862                      -9.75976
# 41                       5.38581                      -1.40562
# 42                     -18.14939                     -27.44857
# 43                      -0.04942                      -0.03947
# 44                     -21.52540                     -35.06812
# 45                      -5.20124                      10.07122
# 46                       0.08909                       9.77786
# 47                      -0.03619                       0.01514
# 48                      -6.26840                      -0.60170
# 49                       0.14284                       0.00148
# 50                       3.66912                      17.88935
# 51                      -1.06343                      -6.10973
# 52                      -5.73471                     -14.42358
# ...
# 24                    8589177240.68000            NaN
# 25                    7657335608.29000            NaN
# 26                    6366386728.66000            NaN
# 27                    7001296079.81000            NaN
# 28                    5544092705.16000            NaN
# 29                    5093394557.98000            NaN
# 30                  563437449524.88000            NaN
# 31                  216683521106.88000            NaN
# 32                   86102882677.30000            NaN
# 33                   48137704550.89000            NaN
# 34                   29607918716.49000            NaN
# 35                   46347407601.62000            NaN
# 36                   16775702511.94000            NaN
# 37                   10150197652.21000            NaN
# 38                   11188256399.80000            NaN
# 39                    8591672174.29000            NaN
# 40                    7669918501.15000            NaN
# 41                    6367271302.70000            NaN
# 42                    7003100928.44000            NaN
# 43                    5543239687.49000            NaN
# 44                    5096617451.12000            NaN
# 45                  564066213705.47998            NaN
# 46                  218672236548.78000            NaN
# 47                   86116975342.36000            NaN
# 48                   48200817118.10000            NaN
# 49                   29422228759.23000            NaN
# 50                   46159658680.62000            NaN
# 51                   16557867017.36000            NaN
# 52                   10182534832.60000            NaN
# 53                    8722744121.85000            NaN
# 54                   10727259020.24000            NaN
# 55                    7056854665.71000            NaN
# 56                    7639297677.07000            NaN
# 57                    6995518952.41000            NaN
# 58                    5500245323.19000            NaN
# 59                    5180467942.68000            NaN
# 60                  564090939654.79004            NaN
# 61                  218685794391.50000            NaN
# 62                   86114824320.63000            NaN
# 63                   48200338419.16000            NaN
# 64                   29422119440.50000            NaN
# 65                   46159002854.03000            NaN
# 66                   16557860733.02000            NaN
# 67                   10182504331.92000            NaN
# 68                    8722419709.47000            NaN
# 69                   10725255024.41000            NaN
# 70                    7057246198.35000            NaN
# 71                    7639541477.21000            NaN
# 72                    6995219795.89000            NaN
# 73                    5500167556.45000            NaN
# 74                    5180560730.13000            NaN
#
#       quote.USD.last_updated  platform.id platform.name platform.symbol  \
# 0   2023-05-18T21:29:00.000Z          NaN           NaN             NaN
# 1   2023-05-18T21:29:00.000Z          NaN           NaN             NaN
# 2   2023-05-18T21:29:00.000Z   1027.00000      Ethereum             ETH
# 3   2023-05-18T21:29:00.000Z          NaN           NaN             NaN
# 4   2023-05-18T21:29:00.000Z   1027.00000      Ethereum             ETH
# 5   2023-05-18T21:29:00.000Z          NaN           NaN             NaN
# 6   2023-05-18T21:29:00.000Z          NaN           NaN             NaN
# 7   2023-05-18T21:29:00.000Z          NaN           NaN             NaN
# 8   2023-05-18T21:29:00.000Z          NaN           NaN             NaN
# 9   2023-05-18T21:29:00.000Z          NaN           NaN             NaN
# 10  2023-05-18T21:29:00.000Z          NaN           NaN             NaN
# 11  2023-05-18T21:29:00.000Z          NaN           NaN             NaN
# 12  2023-05-18T21:29:00.000Z          NaN           NaN             NaN
# 13  2023-05-18T21:29:00.000Z   1839.00000           BNB             BNB
# 14  2023-05-18T21:29:00.000Z   1027.00000      Ethereum             ETH
# 15  2023-05-18T21:30:00.000Z          NaN           NaN             NaN
# 16  2023-05-18T21:30:00.000Z          NaN           NaN             NaN
# 17  2023-05-18T21:30:00.000Z   1027.00000      Ethereum             ETH
# 18  2023-05-18T21:30:00.000Z          NaN           NaN             NaN
# 19  2023-05-18T21:30:00.000Z   1027.00000      Ethereum             ETH
# 20  2023-05-18T21:30:00.000Z          NaN           NaN             NaN
# 21  2023-05-18T21:30:00.000Z          NaN           NaN             NaN
# 22  2023-05-18T21:30:00.000Z          NaN           NaN             NaN
# 23  2023-05-18T21:30:00.000Z          NaN           NaN             NaN
# 24  2023-05-18T21:30:00.000Z          NaN           NaN             NaN
# 25  2023-05-18T21:30:00.000Z          NaN           NaN             NaN
# 26  2023-05-18T21:30:00.000Z          NaN           NaN             NaN
# 27  2023-05-18T21:30:00.000Z          NaN           NaN             NaN
# 28  2023-05-18T21:30:00.000Z   1839.00000           BNB             BNB
# 29  2023-05-18T21:30:00.000Z   1027.00000      Ethereum             ETH
# 30  2023-05-18T21:31:00.000Z          NaN           NaN             NaN
# 31  2023-05-18T21:31:00.000Z          NaN           NaN             NaN
# 32  2023-05-18T21:31:00.000Z   1027.00000      Ethereum             ETH
# 33  2023-05-18T21:31:00.000Z          NaN           NaN             NaN
# 34  2023-05-18T21:31:00.000Z   1027.00000      Ethereum             ETH
# 35  2023-05-18T21:31:00.000Z          NaN           NaN             NaN
# 36  2023-05-18T21:31:00.000Z          NaN           NaN             NaN
# 37  2023-05-18T21:31:00.000Z          NaN           NaN             NaN
# 38  2023-05-18T21:31:00.000Z          NaN           NaN             NaN
# 39  2023-05-18T21:31:00.000Z          NaN           NaN             NaN
# 40  2023-05-18T21:31:00.000Z          NaN           NaN             NaN
# 41  2023-05-18T21:31:00.000Z          NaN           NaN             NaN
# 42  2023-05-18T21:31:00.000Z          NaN           NaN             NaN
# 43  2023-05-18T21:31:00.000Z   1839.00000           BNB             BNB
# 44  2023-05-18T21:31:00.000Z   1027.00000      Ethereum             ETH
# 45  2023-05-22T23:52:00.000Z          NaN           NaN             NaN
# 46  2023-05-22T23:52:00.000Z          NaN           NaN             NaN
# 47  2023-05-22T23:52:00.000Z   1027.00000      Ethereum             ETH
# 48  2023-05-22T23:52:00.000Z          NaN           NaN             NaN
# 49  2023-05-22T23:52:00.000Z   1027.00000      Ethereum             ETH
# 50  2023-05-22T23:52:00.000Z          NaN           NaN             NaN
# 51  2023-05-22T23:52:00.000Z          NaN           NaN             NaN
# 52  2023-05-22T23:52:00.000Z          NaN           NaN             NaN
# 53  2023-05-22T23:52:00.000Z          NaN           NaN             NaN
# 54  2023-05-22T23:52:00.000Z          NaN           NaN             NaN
# 55  2023-05-22T23:52:00.000Z          NaN           NaN             NaN
# 56  2023-05-22T23:52:00.000Z          NaN           NaN             NaN
# 57  2023-05-22T23:52:00.000Z          NaN           NaN             NaN
# 58  2023-05-22T23:52:00.000Z   1839.00000           BNB             BNB
# 59  2023-05-22T23:52:00.000Z   1027.00000      Ethereum             ETH
# 60  2023-05-22T23:53:00.000Z          NaN           NaN             NaN
# 61  2023-05-22T23:53:00.000Z          NaN           NaN             NaN
# 62  2023-05-22T23:53:00.000Z   1027.00000      Ethereum             ETH
# 63  2023-05-22T23:53:00.000Z          NaN           NaN             NaN
# 64  2023-05-22T23:53:00.000Z   1027.00000      Ethereum             ETH
# 65  2023-05-22T23:53:00.000Z          NaN           NaN             NaN
# 66  2023-05-22T23:53:00.000Z          NaN           NaN             NaN
# 67  2023-05-22T23:53:00.000Z          NaN           NaN             NaN
# 68  2023-05-22T23:53:00.000Z          NaN           NaN             NaN
# 69  2023-05-22T23:53:00.000Z          NaN           NaN             NaN
# 70  2023-05-22T23:53:00.000Z          NaN           NaN             NaN
# 71  2023-05-22T23:53:00.000Z          NaN           NaN             NaN
# 72  2023-05-22T23:53:00.000Z          NaN           NaN             NaN
# 73  2023-05-22T23:53:00.000Z   1839.00000           BNB             BNB
# 74  2023-05-22T23:53:00.000Z   1027.00000      Ethereum             ETH
#
#    platform.slug                      platform.token_address  \
# 0            NaN                                         NaN
# 1            NaN                                         NaN
# 2       ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3            NaN                                         NaN
# 4       ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 5            NaN                                         NaN
# 6            NaN                                         NaN
# 7            NaN                                         NaN
# 8            NaN                                         NaN
# 9            NaN                                         NaN
# 10           NaN                                         NaN
# 11           NaN                                         NaN
# 12           NaN                                         NaN
# 13           bnb                                    BUSD-BD1
# 14      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 15           NaN                                         NaN
# 16           NaN                                         NaN
# 17      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 18           NaN                                         NaN
# 19      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 20           NaN                                         NaN
# 21           NaN                                         NaN
# 22           NaN                                         NaN
# 23           NaN                                         NaN
# 24           NaN                                         NaN
# 25           NaN                                         NaN
# 26           NaN                                         NaN
# 27           NaN                                         NaN
# 28           bnb                                    BUSD-BD1
# 29      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 30           NaN                                         NaN
# 31           NaN                                         NaN
# 32      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 33           NaN                                         NaN
# 34      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 35           NaN                                         NaN
# 36           NaN                                         NaN
# 37           NaN                                         NaN
# 38           NaN                                         NaN
# 39           NaN                                         NaN
# 40           NaN                                         NaN
# 41           NaN                                         NaN
# 42           NaN                                         NaN
# 43           bnb                                    BUSD-BD1
# 44      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 45           NaN                                         NaN
# 46           NaN                                         NaN
# 47      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 48           NaN                                         NaN
# 49      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 50           NaN                                         NaN
# 51           NaN                                         NaN
# 52           NaN                                         NaN
# 53           NaN                                         NaN
# 54           NaN                                         NaN
# 55           NaN                                         NaN
# 56           NaN                                         NaN
# 57           NaN                                         NaN
# 58           bnb                                    BUSD-BD1
# 59      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
# 60           NaN                                         NaN
# 61           NaN                                         NaN
# 62      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 63           NaN                                         NaN
# 64      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 65           NaN                                         NaN
# 66           NaN                                         NaN
# 67           NaN                                         NaN
# 68           NaN                                         NaN
# 69           NaN                                         NaN
# 70           NaN                                         NaN
# 71           NaN                                         NaN
# 72           NaN                                         NaN
# 73           bnb                                    BUSD-BD1
# 74      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
#
#                      timestamp
# 0   2023-05-18 21:30:43.299581
# 1   2023-05-18 21:30:43.299581
# 2   2023-05-18 21:30:43.299581
# 3   2023-05-18 21:30:43.299581
# 4   2023-05-18 21:30:43.299581
# 5   2023-05-18 21:30:43.299581
# 6   2023-05-18 21:30:43.299581
# 7   2023-05-18 21:30:43.299581
# 8   2023-05-18 21:30:43.299581
# 9   2023-05-18 21:30:43.299581
# 10  2023-05-18 21:30:43.299581
# 11  2023-05-18 21:30:43.299581
# 12  2023-05-18 21:30:43.299581
# 13  2023-05-18 21:30:43.299581
# 14  2023-05-18 21:30:43.299581
# 15  2023-05-18 21:32:08.024563
# 16  2023-05-18 21:32:08.024563
# 17  2023-05-18 21:32:08.024563
# 18  2023-05-18 21:32:08.024563
# 19  2023-05-18 21:32:08.024563
# 20  2023-05-18 21:32:08.024563
# 21  2023-05-18 21:32:08.024563
# 22  2023-05-18 21:32:08.024563
# 23  2023-05-18 21:32:08.024563
# 24  2023-05-18 21:32:08.024563
# 25  2023-05-18 21:32:08.024563
# 26  2023-05-18 21:32:08.024563
# 27  2023-05-18 21:32:08.024563
# 28  2023-05-18 21:32:08.024563
# 29  2023-05-18 21:32:08.024563
# 30  2023-05-18 21:33:08.305762
# 31  2023-05-18 21:33:08.305762
# 32  2023-05-18 21:33:08.305762
# 33  2023-05-18 21:33:08.305762
# 34  2023-05-18 21:33:08.305762
# 35  2023-05-18 21:33:08.305762
# 36  2023-05-18 21:33:08.305762
# 37  2023-05-18 21:33:08.305762
# 38  2023-05-18 21:33:08.305762
# 39  2023-05-18 21:33:08.305762
# 40  2023-05-18 21:33:08.305762
# 41  2023-05-18 21:33:08.305762
# 42  2023-05-18 21:33:08.305762
# 43  2023-05-18 21:33:08.305762
# 44  2023-05-18 21:33:08.305762
# 45  2023-05-22 23:53:37.283961
# 46  2023-05-22 23:53:37.283961
# 47  2023-05-22 23:53:37.283961
# 48  2023-05-22 23:53:37.283961
# 49  2023-05-22 23:53:37.283961
# 50  2023-05-22 23:53:37.283961
# 51  2023-05-22 23:53:37.283961
# 52  2023-05-22 23:53:37.283961
# 53  2023-05-22 23:53:37.283961
# 54  2023-05-22 23:53:37.283961
# 55  2023-05-22 23:53:37.283961
# 56  2023-05-22 23:53:37.283961
# 57  2023-05-22 23:53:37.283961
# 58  2023-05-22 23:53:37.283961
# 59  2023-05-22 23:53:37.283961
# 60  2023-05-22 23:54:37.763551
# 61  2023-05-22 23:54:37.763551
# 62  2023-05-22 23:54:37.763551
# 63  2023-05-22 23:54:37.763551
# 64  2023-05-22 23:54:37.763551
# 65  2023-05-22 23:54:37.763551
# 66  2023-05-22 23:54:37.763551
# 67  2023-05-22 23:54:37.763551
# 68  2023-05-22 23:54:37.763551
# 69  2023-05-22 23:54:37.763551
# 70  2023-05-22 23:54:37.763551
# 71  2023-05-22 23:54:37.763551
# 72  2023-05-22 23:54:37.763551
# 73  2023-05-22 23:54:37.763551
# 74  2023-05-22 23:54:37.763551

# %%
df
# Out:
#       id         name symbol          slug  num_market_pairs  \
# 0      1      Bitcoin    BTC       bitcoin             10221
# 1   1027     Ethereum    ETH      ethereum              6933
# 2    825       Tether   USDT        tether             53878
# 3   1839          BNB    BNB           bnb              1387
# 4   3408     USD Coin   USDC      usd-coin             12582
# 5     52          XRP    XRP           xrp               951
# 6   2010      Cardano    ADA       cardano               790
# 7     74     Dogecoin   DOGE      dogecoin               711
# 8   3890      Polygon  MATIC       polygon               709
# 9   5426       Solana    SOL        solana               463
# 10  1958         TRON    TRX          tron               759
# 11     2     Litecoin    LTC      litecoin               912
# 12  6636     Polkadot    DOT  polkadot-new               502
# 13  4687  Binance USD   BUSD   binance-usd              6787
# 14  5994    Shiba Inu   SHIB     shiba-inu               526
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2018-10-08T00:00:00.000Z
# 5   2013-08-04T00:00:00.000Z
# 6   2017-10-01T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2019-04-28T00:00:00.000Z
# 9   2020-04-10T00:00:00.000Z
# 10  2017-09-13T00:00:00.000Z
# 11  2013-04-28T00:00:00.000Z
# 12  2020-08-19T00:00:00.000Z
# 13  2019-09-20T00:00:00.000Z
# 14  2020-08-01T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...           NaN
# 3   [marketplace, centralized-exchange, payments, ...           NaN
# 4   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 5   [medium-of-exchange, enterprise-solutions, arr...  1.000000e+11
# 6   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 7   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 8   [platform, enterprise-solutions, zero-knowledg...  1.000000e+10
# 9   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 10                  [media, payments, tron-ecosystem]           NaN
# 11        [mineable, pow, scrypt, medium-of-exchange]  8.400000e+07
# 12  [substrate, polkadot, binance-chain, polkadot-...           NaN
# 13  [stablecoin, asset-backed-stablecoin, binance-...           NaN
# 14      [memes, ethereum-ecosystem, doggone-doggerel]           NaN
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.938090e+07  1.938090e+07            False       NaN         1
# 1         1.202694e+08  1.202694e+08             True       NaN         2
# 2         8.291908e+10  8.609064e+10             True       NaN         3
# 3         1.558582e+08  1.558582e+08            False       NaN         4
# 4         2.942094e+10  2.942094e+10            False       NaN         5
# 5         5.187315e+10  9.998893e+10            False       NaN         6
# 6         3.486311e+10  3.581044e+10            False       NaN         7
# 7         1.394561e+11  1.394561e+11             True       NaN         8
# 8         9.279469e+09  1.000000e+10            False       NaN         9
# 9         3.960871e+08  5.483048e+08             True       NaN        10
# 10        9.033444e+10  9.033445e+10             True       NaN        11
# 11        7.297924e+07  8.400000e+07            False       NaN        12
# 12        1.186504e+09  1.315983e+09             True       NaN        13
# 13        5.499802e+09  5.499802e+09             True       NaN        14
# 14        5.895343e+14  5.895977e+14            False       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap tvl_ratio  \
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# 5                                NaN                       NaN      None
# 6                                NaN                       NaN      None
# 7                                NaN                       NaN      None
# 8                                NaN                       NaN      None
# 9                                NaN                       NaN      None
# 10                      7.165966e+10              5.598305e+09      None
# 11                               NaN                       NaN      None
# 12                               NaN                       NaN      None
# 13                               NaN                       NaN      None
# 14                               NaN                       NaN      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2023-05-22T23:53:00.000Z     26861.473317          1.106529e+10
# 1   2023-05-22T23:53:00.000Z      1818.299394          4.541630e+09
# 2   2023-05-22T23:53:00.000Z         1.000281          1.722268e+10
# 3   2023-05-22T23:53:00.000Z       309.257699          3.550722e+08
# 4   2023-05-22T23:53:00.000Z         1.000040          2.589336e+09
# 5   2023-05-22T23:53:00.000Z         0.461590          9.050756e+08
# 6   2023-05-22T23:53:00.000Z         0.367952          1.780521e+08
# 7   2023-05-22T23:53:00.000Z         0.073016          2.099066e+08
# 8   2023-05-22T23:53:00.000Z         0.872242          2.476857e+08
# 9   2023-05-22T23:53:00.000Z        19.560754          2.164972e+08
# 10  2023-05-22T23:53:00.000Z         0.078124          4.006520e+08
# 11  2023-05-22T23:53:00.000Z        90.946922          3.975789e+08
# 12  2023-05-22T23:53:00.000Z         5.315584          9.077964e+07
# 13  2023-05-22T23:53:00.000Z         1.000067          1.789028e+09
# 14  2023-05-22T23:53:00.000Z         0.000009          1.546590e+08
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                       28.0501                    -0.074064
# 1                       34.2415                    -0.066060
# 2                       27.3261                     0.000418
# 3                       17.3303                    -0.121457
# 4                       45.7462                     0.001885
# 5                       68.7044                     0.085480
# 6                       53.0747                    -0.101029
# 7                       47.7530                    -0.065047
# 8                       28.0845                     0.005484
# 9                        3.1502                    -0.306240
# 10                      18.8552                    -0.411857
# 11                       8.9785                    -0.134857
# 12                       8.2119                     0.008540
# 13                      29.6570                     0.013548
# 14                     131.5230                     0.124750
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       0.383590                    -1.234770
# 1                       0.774581                     0.014577
# 2                       0.007241                    -0.005170
# 3                       0.870495                    -1.359232
# 4                       0.014716                    -0.001430
# 5                       0.752386                     8.003799
# 6                       1.995546                     0.122683
# 7                       1.150899                     1.320004
# 8                       1.729712                     1.371635
# 9                      -0.447424                    -6.877449
# 10                      3.867540                    11.236714
# 11                     -1.556480                     4.351852
# 12                      0.719416                    -0.095876
# 13                      0.024329                     0.010911
# 14                      2.918301                    -0.261143
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                      -3.410611                     -5.200919
# 1                      -2.999953                      0.079138
# 2                       0.003866                     -0.077201
# 3                      -6.904451                     -6.266092
# 4                      -0.008406                      0.100891
# 5                      -2.354623                      3.675414
# 6                      -7.091233                     -1.072255
# 7                      -9.249157                     -5.739535
# 8                     -14.954078                    -23.280824
# 9                     -10.362840                    -11.982627
# 10                     18.315834                     19.567956
# 11                      4.367723                     -2.859190
# 12                    -10.725704                    -15.970816
# 13                      0.009734                      0.011418
# 14                    -16.046560                    -19.079005
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      10.051393          5.205995e+11
# 1                       9.757727          2.186858e+11
# 2                       0.013536          8.294237e+10
# 3                      -0.622514          4.820034e+10
# 4                      -0.002914          2.942212e+10
# 5                      17.874071          2.394413e+10
# 6                      -6.126921          1.282797e+10
# 7                     -14.436673          1.018250e+10
# 8                     -36.896504          8.093942e+09
# 9                     -21.451226          7.747762e+09
# 10                     12.528447          7.057245e+09
# 11                     -2.830824          6.637237e+09
# 12                    -26.630077          6.306964e+09
# 13                     -0.020962          5.500168e+09
# 14                    -32.668421          5.180004e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          46.3116                        5.640909e+11
# 1                          19.4539                        2.186858e+11
# 2                           7.3784                        8.611482e+10
# 3                           4.2878                        4.820034e+10
# 4                           2.6173                        2.942212e+10
# 5                           2.1302                        4.615900e+10
# 6                           1.1412                        1.655786e+10
# 7                           0.9058                        1.018250e+10
# 8                           0.7200                        8.722420e+09
# 9                           0.6892                        1.072526e+10
# 10                          0.6278                        7.057246e+09
# 11                          0.5904                        7.639541e+09
# 12                          0.5611                        6.995220e+09
# 13                          0.4893                        5.500168e+09
# 14                          0.4608                        5.180561e+09
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2023-05-22T23:53:00.000Z          NaN           NaN
# 1           None  2023-05-22T23:53:00.000Z          NaN           NaN
# 2           None  2023-05-22T23:53:00.000Z       1027.0      Ethereum
# 3           None  2023-05-22T23:53:00.000Z          NaN           NaN
# 4           None  2023-05-22T23:53:00.000Z       1027.0      Ethereum
# 5           None  2023-05-22T23:53:00.000Z          NaN           NaN
# 6           None  2023-05-22T23:53:00.000Z          NaN           NaN
# 7           None  2023-05-22T23:53:00.000Z          NaN           NaN
# 8           None  2023-05-22T23:53:00.000Z          NaN           NaN
# 9           None  2023-05-22T23:53:00.000Z          NaN           NaN
# 10          None  2023-05-22T23:53:00.000Z          NaN           NaN
# 11          None  2023-05-22T23:53:00.000Z          NaN           NaN
# 12          None  2023-05-22T23:53:00.000Z          NaN           NaN
# 13          None  2023-05-22T23:53:00.000Z       1839.0           BNB
# 14          None  2023-05-22T23:53:00.000Z       1027.0      Ethereum
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 5              NaN           NaN                                         NaN
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             NaN           NaN                                         NaN
# 13             BNB           bnb                                    BUSD-BD1
# 14             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
#
#                     timestamp
# 0  2023-05-22 23:54:37.763551
# 1  2023-05-22 23:54:37.763551
# 2  2023-05-22 23:54:37.763551
# 3  2023-05-22 23:54:37.763551
# 4  2023-05-22 23:54:37.763551
# 5  2023-05-22 23:54:37.763551
# 6  2023-05-22 23:54:37.763551
# 7  2023-05-22 23:54:37.763551
# 8  2023-05-22 23:54:37.763551
# 9  2023-05-22 23:54:37.763551
# 10 2023-05-22 23:54:37.763551
# 11 2023-05-22 23:54:37.763551
# 12 2023-05-22 23:54:37.763551
# 13 2023-05-22 23:54:37.763551
# 14 2023-05-22 23:54:37.763551

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
#       id         name symbol          slug  num_market_pairs  \
# 0      1      Bitcoin    BTC       bitcoin             10221
# 1   1027     Ethereum    ETH      ethereum              6933
# 2    825       Tether   USDT        tether             53878
# 3   1839          BNB    BNB           bnb              1387
# 4   3408     USD Coin   USDC      usd-coin             12582
# 5     52          XRP    XRP           xrp               951
# 6   2010      Cardano    ADA       cardano               790
# 7     74     Dogecoin   DOGE      dogecoin               711
# 8   3890      Polygon  MATIC       polygon               709
# 9   5426       Solana    SOL        solana               463
# 10  1958         TRON    TRX          tron               759
# 11     2     Litecoin    LTC      litecoin               912
# 12  6636     Polkadot    DOT  polkadot-new               502
# 13  4687  Binance USD   BUSD   binance-usd              6787
# 14  5994    Shiba Inu   SHIB     shiba-inu               526
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2017-07-25T00:00:00.000Z
# 4   2018-10-08T00:00:00.000Z
# 5   2013-08-04T00:00:00.000Z
# 6   2017-10-01T00:00:00.000Z
# 7   2013-12-15T00:00:00.000Z
# 8   2019-04-28T00:00:00.000Z
# 9   2020-04-10T00:00:00.000Z
# 10  2017-09-13T00:00:00.000Z
# 11  2013-04-28T00:00:00.000Z
# 12  2020-08-19T00:00:00.000Z
# 13  2019-09-20T00:00:00.000Z
# 14  2020-08-01T00:00:00.000Z
#
#                                                  tags         max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...     21000000.00000
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...                NaN
# 2   [payments, stablecoin, asset-backed-stablecoin...                NaN
# 3   [marketplace, centralized-exchange, payments, ...                NaN
# 4   [medium-of-exchange, stablecoin, asset-backed-...                NaN
# 5   [medium-of-exchange, enterprise-solutions, arr... 100000000000.00000
# 6   [dpos, pos, platform, research, smart-contract...  45000000000.00000
# 7   [mineable, pow, scrypt, medium-of-exchange, me...                NaN
# 8   [platform, enterprise-solutions, zero-knowledg...  10000000000.00000
# 9   [pos, platform, solana-ecosystem, cms-holdings...                NaN
# 10                  [media, payments, tron-ecosystem]                NaN
# 11        [mineable, pow, scrypt, medium-of-exchange]     84000000.00000
# 12  [substrate, polkadot, binance-chain, polkadot-...                NaN
# 13  [stablecoin, asset-backed-stablecoin, binance-...                NaN
# 14      [memes, ethereum-ecosystem, doggone-doggerel]                NaN
#
#       circulating_supply          total_supply  infinite_supply  platform  \
# 0         19380900.00000        19380900.00000            False       NaN
# 1        120269409.46943       120269409.46943             True       NaN
# 2      82919078535.20427     86090638895.05328             True       NaN
# 3        155858168.20289       155858168.20289            False       NaN
# 4      29420939250.75391     29420939250.75391            False       NaN
# 5      51873152538.00000     99988934739.00000            False       NaN
# 6      34863111584.60900     35810438256.57800            False       NaN
# 7     139456066383.70523    139456066383.70523             True       NaN
# 8       9279469069.28493     10000000000.00000            False       NaN
# 9        396087084.31639       548304788.49960             True       NaN
# 10     90334442435.67618     90334453637.35883             True       NaN
# 11        72979239.30932        84000000.00000            False       NaN
# 12      1186504407.85935      1315983285.16453             True       NaN
# 13      5499801594.05338      5499801594.05338             True       NaN
# 14 589534333568906.25000 589597746628688.62500            False       NaN
#
#     cmc_rank  self_reported_circulating_supply  self_reported_market_cap  \
# 0          1                               NaN                       NaN
# 1          2                               NaN                       NaN
# 2          3                               NaN                       NaN
# 3          4                               NaN                       NaN
# 4          5                               NaN                       NaN
# 5          6                               NaN                       NaN
# 6          7                               NaN                       NaN
# 7          8                               NaN                       NaN
# 8          9                               NaN                       NaN
# 9         10                               NaN                       NaN
# 10        11                 71659659264.00000          5598305381.31073
# 11        12                               NaN                       NaN
# 12        13                               NaN                       NaN
# 13        14                               NaN                       NaN
# 14        15                               NaN                       NaN
#
#    tvl_ratio              last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0       None  2023-05-22T23:53:00.000Z      26861.47332     11065288535.10376
# 1       None  2023-05-22T23:53:00.000Z       1818.29939      4541630296.77448
# 2       None  2023-05-22T23:53:00.000Z          1.00028     17222675171.24683
# 3       None  2023-05-22T23:53:00.000Z        309.25770       355072240.41954
# 4       None  2023-05-22T23:53:00.000Z          1.00004      2589335523.53087
# 5       None  2023-05-22T23:53:00.000Z          0.46159       905075636.89414
# 6       None  2023-05-22T23:53:00.000Z          0.36795       178052051.95489
# 7       None  2023-05-22T23:53:00.000Z          0.07302       209906553.30820
# 8       None  2023-05-22T23:53:00.000Z          0.87224       247685678.69089
# 9       None  2023-05-22T23:53:00.000Z         19.56075       216497190.47518
# 10      None  2023-05-22T23:53:00.000Z          0.07812       400652019.92939
# 11      None  2023-05-22T23:53:00.000Z         90.94692       397578877.30467
# 12      None  2023-05-22T23:53:00.000Z          5.31558        90779640.31612
# 13      None  2023-05-22T23:53:00.000Z          1.00007      1789028049.93932
# 14      None  2023-05-22T23:53:00.000Z          0.00001       154658994.14813
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                      28.05010                     -0.07406
# 1                      34.24150                     -0.06606
# 2                      27.32610                      0.00042
# 3                      17.33030                     -0.12146
# 4                      45.74620                      0.00188
# 5                      68.70440                      0.08548
# 6                      53.07470                     -0.10103
# 7                      47.75300                     -0.06505
# 8                      28.08450                      0.00548
# 9                       3.15020                     -0.30624
# 10                     18.85520                     -0.41186
# 11                      8.97850                     -0.13486
# 12                      8.21190                      0.00854
# 13                     29.65700                      0.01355
# 14                    131.52300                      0.12475
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                        0.38359                     -1.23477
# 1                        0.77458                      0.01458
# 2                        0.00724                     -0.00517
# 3                        0.87049                     -1.35923
# 4                        0.01472                     -0.00143
# 5                        0.75239                      8.00380
# 6                        1.99555                      0.12268
# 7                        1.15090                      1.32000
# 8                        1.72971                      1.37163
# 9                       -0.44742                     -6.87745
# 10                       3.86754                     11.23671
# 11                      -1.55648                      4.35185
# 12                       0.71942                     -0.09588
# 13                       0.02433                      0.01091
# 14                       2.91830                     -0.26114
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                       -3.41061                      -5.20092
# 1                       -2.99995                       0.07914
# 2                        0.00387                      -0.07720
# 3                       -6.90445                      -6.26609
# 4                       -0.00841                       0.10089
# 5                       -2.35462                       3.67541
# 6                       -7.09123                      -1.07225
# 7                       -9.24916                      -5.73953
# 8                      -14.95408                     -23.28082
# 9                      -10.36284                     -11.98263
# 10                      18.31583                      19.56796
# 11                       4.36772                      -2.85919
# 12                     -10.72570                     -15.97082
# 13                       0.00973                       0.01142
# 14                     -16.04656                     -19.07900
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                       10.05139    520599528207.40613
# 1                        9.75773    218685794391.49713
# 2                        0.01354     82942372974.98216
# 3                       -0.62251     48200338419.16485
# 4                       -0.00291     29422119440.49678
# 5                       17.87407     23944129960.49221
# 6                       -6.12692     12827967696.39090
# 7                      -14.43667     10182504331.91587
# 8                      -36.89650      8093942390.33196
# 9                      -21.45123      7747761975.21895
# 10                      12.52845      7057245323.23323
# 11                      -2.83082      6637237210.46446
# 12                     -26.63008      6306963937.41555
# 13                      -0.02096      5500167556.44861
# 14                     -32.66842      5180003544.81477
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                         46.31160                  564090939654.79004
# 1                         19.45390                  218685794391.50000
# 2                          7.37840                   86114824320.63000
# 3                          4.28780                   48200338419.16000
# 4                          2.61730                   29422119440.50000
# 5                          2.13020                   46159002854.03000
# 6                          1.14120                   16557860733.02000
# 7                          0.90580                   10182504331.92000
# 8                          0.72000                    8722419709.47000
# 9                          0.68920                   10725255024.41000
# 10                         0.62780                    7057246198.35000
# 11                         0.59040                    7639541477.21000
# 12                         0.56110                    6995219795.89000
# 13                         0.48930                    5500167556.45000
# 14                         0.46080                    5180560730.13000
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2023-05-22T23:53:00.000Z          NaN           NaN
# 1           None  2023-05-22T23:53:00.000Z          NaN           NaN
# 2           None  2023-05-22T23:53:00.000Z   1027.00000      Ethereum
# 3           None  2023-05-22T23:53:00.000Z          NaN           NaN
# 4           None  2023-05-22T23:53:00.000Z   1027.00000      Ethereum
# 5           None  2023-05-22T23:53:00.000Z          NaN           NaN
# 6           None  2023-05-22T23:53:00.000Z          NaN           NaN
# 7           None  2023-05-22T23:53:00.000Z          NaN           NaN
# 8           None  2023-05-22T23:53:00.000Z          NaN           NaN
# 9           None  2023-05-22T23:53:00.000Z          NaN           NaN
# 10          None  2023-05-22T23:53:00.000Z          NaN           NaN
# 11          None  2023-05-22T23:53:00.000Z          NaN           NaN
# 12          None  2023-05-22T23:53:00.000Z          NaN           NaN
# 13          None  2023-05-22T23:53:00.000Z   1839.00000           BNB
# 14          None  2023-05-22T23:53:00.000Z   1027.00000      Ethereum
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 5              NaN           NaN                                         NaN
# 6              NaN           NaN                                         NaN
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10             NaN           NaN                                         NaN
# 11             NaN           NaN                                         NaN
# 12             NaN           NaN                                         NaN
# 13             BNB           bnb                                    BUSD-BD1
# 14             ETH      ethereum  0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce
#
#                     timestamp
# 0  2023-05-22 23:54:37.763551
# 1  2023-05-22 23:54:37.763551
# 2  2023-05-22 23:54:37.763551
# 3  2023-05-22 23:54:37.763551
# 4  2023-05-22 23:54:37.763551
# 5  2023-05-22 23:54:37.763551
# 6  2023-05-22 23:54:37.763551
# 7  2023-05-22 23:54:37.763551
# 8  2023-05-22 23:54:37.763551
# 9  2023-05-22 23:54:37.763551
# 10 2023-05-22 23:54:37.763551
# 11 2023-05-22 23:54:37.763551
# 12 2023-05-22 23:54:37.763551
# 13 2023-05-22 23:54:37.763551
# 14 2023-05-22 23:54:37.763551

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h', 'quote.USD.percent_change_7d', 'quote.USD.percent_change_30d', 'quote.USD.percent_change_60d', 'quote.USD.percent_change_90d']].mean()

# %%
df3
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                         -0.07406                       0.38359
# Ethereum                        -0.06606                       0.77458
# Tether                           0.00042                       0.00724
# BNB                             -0.12146                       0.87049
# USD Coin                         0.00188                       0.01472
# XRP                              0.08548                       0.75239
# Cardano                         -0.10103                       1.99555
# Dogecoin                        -0.06505                       1.15090
# Polygon                          0.00548                       1.72971
# Solana                          -0.30624                      -0.44742
# TRON                            -0.41186                       3.86754
# Litecoin                        -0.13486                      -1.55648
# Polkadot                         0.00854                       0.71942
# Binance USD                      0.01355                       0.02433
# Shiba Inu                        0.12475                       2.91830
#
#              quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# name
# Bitcoin                         -1.23477                      -3.41061
# Ethereum                         0.01458                      -2.99995
# Tether                          -0.00517                       0.00387
# BNB                             -1.35923                      -6.90445
# USD Coin                        -0.00143                      -0.00841
# XRP                              8.00380                      -2.35462
# Cardano                          0.12268                      -7.09123
# Dogecoin                         1.32000                      -9.24916
# Polygon                          1.37163                     -14.95408
# Solana                          -6.87745                     -10.36284
# TRON                            11.23671                      18.31583
# Litecoin                         4.35185                       4.36772
# Polkadot                        -0.09588                     -10.72570
# Binance USD                      0.01091                       0.00973
# Shiba Inu                       -0.26114                     -16.04656
#
#              quote.USD.percent_change_60d  quote.USD.percent_change_90d
# name
# Bitcoin                          -5.20092                      10.05139
# Ethereum                          0.07914                       9.75773
# Tether                           -0.07720                       0.01354
# BNB                              -6.26609                      -0.62251
# USD Coin                          0.10089                      -0.00291
# XRP                               3.67541                      17.87407
# Cardano                          -1.07225                      -6.12692
# Dogecoin                         -5.73953                     -14.43667
# Polygon                         -23.28082                     -36.89650
# Solana                          -11.98263                     -21.45123
# TRON                             19.56796                      12.52845
# Litecoin                         -2.85919                      -2.83082
# Polkadot                        -15.97082                     -26.63008
# Binance USD                       0.01142                      -0.02096
# Shiba Inu                       -19.07900                     -32.66842

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin      quote.USD.percent_change_1h     -0.07406
#              quote.USD.percent_change_24h     0.38359
#              quote.USD.percent_change_7d     -1.23477
#              quote.USD.percent_change_30d    -3.41061
#              quote.USD.percent_change_60d    -5.20092
#              quote.USD.percent_change_90d    10.05139
# Ethereum     quote.USD.percent_change_1h     -0.06606
#              quote.USD.percent_change_24h     0.77458
#              quote.USD.percent_change_7d      0.01458
#              quote.USD.percent_change_30d    -2.99995
#              quote.USD.percent_change_60d     0.07914
#              quote.USD.percent_change_90d     9.75773
# Tether       quote.USD.percent_change_1h      0.00042
#              quote.USD.percent_change_24h     0.00724
#              quote.USD.percent_change_7d     -0.00517
#              quote.USD.percent_change_30d     0.00387
#              quote.USD.percent_change_60d    -0.07720
#              quote.USD.percent_change_90d     0.01354
# BNB          quote.USD.percent_change_1h     -0.12146
#              quote.USD.percent_change_24h     0.87049
#              quote.USD.percent_change_7d     -1.35923
#              quote.USD.percent_change_30d    -6.90445
#              quote.USD.percent_change_60d    -6.26609
#              quote.USD.percent_change_90d    -0.62251
# USD Coin     quote.USD.percent_change_1h      0.00188
#              quote.USD.percent_change_24h     0.01472
#              quote.USD.percent_change_7d     -0.00143
#              quote.USD.percent_change_30d    -0.00841
#              quote.USD.percent_change_60d     0.10089
#              quote.USD.percent_change_90d    -0.00291
# XRP          quote.USD.percent_change_1h      0.08548
#              quote.USD.percent_change_24h     0.75239
#              quote.USD.percent_change_7d      8.00380
#              quote.USD.percent_change_30d    -2.35462
#              quote.USD.percent_change_60d     3.67541
#              quote.USD.percent_change_90d    17.87407
# Cardano      quote.USD.percent_change_1h     -0.10103
#              quote.USD.percent_change_24h     1.99555
#              quote.USD.percent_change_7d      0.12268
#              quote.USD.percent_change_30d    -7.09123
#              quote.USD.percent_change_60d    -1.07225
#              quote.USD.percent_change_90d    -6.12692
# Dogecoin     quote.USD.percent_change_1h     -0.06505
#              quote.USD.percent_change_24h     1.15090
#              quote.USD.percent_change_7d      1.32000
#              quote.USD.percent_change_30d    -9.24916
#              quote.USD.percent_change_60d    -5.73953
#              quote.USD.percent_change_90d   -14.43667
# Polygon      quote.USD.percent_change_1h      0.00548
#              quote.USD.percent_change_24h     1.72971
#              quote.USD.percent_change_7d      1.37163
#              quote.USD.percent_change_30d   -14.95408
#              quote.USD.percent_change_60d   -23.28082
#              quote.USD.percent_change_90d   -36.89650
# Solana       quote.USD.percent_change_1h     -0.30624
#              quote.USD.percent_change_24h    -0.44742
#              quote.USD.percent_change_7d     -6.87745
#              quote.USD.percent_change_30d   -10.36284
#              quote.USD.percent_change_60d   -11.98263
#              quote.USD.percent_change_90d   -21.45123
# TRON         quote.USD.percent_change_1h     -0.41186
#              quote.USD.percent_change_24h     3.86754
#              quote.USD.percent_change_7d     11.23671
#              quote.USD.percent_change_30d    18.31583
#              quote.USD.percent_change_60d    19.56796
#              quote.USD.percent_change_90d    12.52845
# Litecoin     quote.USD.percent_change_1h     -0.13486
#              quote.USD.percent_change_24h    -1.55648
#              quote.USD.percent_change_7d      4.35185
#              quote.USD.percent_change_30d     4.36772
#              quote.USD.percent_change_60d    -2.85919
#              quote.USD.percent_change_90d    -2.83082
# Polkadot     quote.USD.percent_change_1h      0.00854
#              quote.USD.percent_change_24h     0.71942
#              quote.USD.percent_change_7d     -0.09588
#              quote.USD.percent_change_30d   -10.72570
#              quote.USD.percent_change_60d   -15.97082
#              quote.USD.percent_change_90d   -26.63008
# Binance USD  quote.USD.percent_change_1h      0.01355
#              quote.USD.percent_change_24h     0.02433
#              quote.USD.percent_change_7d      0.01091
#              quote.USD.percent_change_30d     0.00973
#              quote.USD.percent_change_60d     0.01142
#              quote.USD.percent_change_90d    -0.02096
# Shiba Inu    quote.USD.percent_change_1h      0.12475
#              quote.USD.percent_change_24h     2.91830
#              quote.USD.percent_change_7d     -0.26114
#              quote.USD.percent_change_30d   -16.04656
#              quote.USD.percent_change_60d   -19.07900
#              quote.USD.percent_change_90d   -32.66842
# dtype: float64

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                             values
# name
# Bitcoin     quote.USD.percent_change_1h   -0.07406
#             quote.USD.percent_change_24h   0.38359
#             quote.USD.percent_change_7d   -1.23477
#             quote.USD.percent_change_30d  -3.41061
#             quote.USD.percent_change_60d  -5.20092
#             quote.USD.percent_change_90d  10.05139
# Ethereum    quote.USD.percent_change_1h   -0.06606
#             quote.USD.percent_change_24h   0.77458
#             quote.USD.percent_change_7d    0.01458
#             quote.USD.percent_change_30d  -2.99995
#             quote.USD.percent_change_60d   0.07914
#             quote.USD.percent_change_90d   9.75773
# Tether      quote.USD.percent_change_1h    0.00042
#             quote.USD.percent_change_24h   0.00724
#             quote.USD.percent_change_7d   -0.00517
#             quote.USD.percent_change_30d   0.00387
#             quote.USD.percent_change_60d  -0.07720
#             quote.USD.percent_change_90d   0.01354
# BNB         quote.USD.percent_change_1h   -0.12146
#             quote.USD.percent_change_24h   0.87049
#             quote.USD.percent_change_7d   -1.35923
#             quote.USD.percent_change_30d  -6.90445
#             quote.USD.percent_change_60d  -6.26609
#             quote.USD.percent_change_90d  -0.62251
# USD Coin    quote.USD.percent_change_1h    0.00188
#             quote.USD.percent_change_24h   0.01472
#             quote.USD.percent_change_7d   -0.00143
#             quote.USD.percent_change_30d  -0.00841
#             quote.USD.percent_change_60d   0.10089
#             quote.USD.percent_change_90d  -0.00291
# XRP         quote.USD.percent_change_1h    0.08548
#             quote.USD.percent_change_24h   0.75239
#             quote.USD.percent_change_7d    8.00380
#             quote.USD.percent_change_30d  -2.35462
#             quote.USD.percent_change_60d   3.67541
#             quote.USD.percent_change_90d  17.87407
# Cardano     quote.USD.percent_change_1h   -0.10103
#             quote.USD.percent_change_24h   1.99555
#             quote.USD.percent_change_7d    0.12268
#             quote.USD.percent_change_30d  -7.09123
#             quote.USD.percent_change_60d  -1.07225
#             quote.USD.percent_change_90d  -6.12692
# Dogecoin    quote.USD.percent_change_1h   -0.06505
#             quote.USD.percent_change_24h   1.15090
#             quote.USD.percent_change_7d    1.32000
#             quote.USD.percent_change_30d  -9.24916
#             quote.USD.percent_change_60d  -5.73953
#             quote.USD.percent_change_90d -14.43667
# Polygon     quote.USD.percent_change_1h    0.00548
#             quote.USD.percent_change_24h   1.72971
#             quote.USD.percent_change_7d    1.37163
#             quote.USD.percent_change_30d -14.95408
#             quote.USD.percent_change_60d -23.28082
#             quote.USD.percent_change_90d -36.89650
# Solana      quote.USD.percent_change_1h   -0.30624
#             quote.USD.percent_change_24h  -0.44742
#             quote.USD.percent_change_7d   -6.87745
#             quote.USD.percent_change_30d -10.36284
#             quote.USD.percent_change_60d -11.98263
#             quote.USD.percent_change_90d -21.45123
# TRON        quote.USD.percent_change_1h   -0.41186
#             quote.USD.percent_change_24h   3.86754
#             quote.USD.percent_change_7d   11.23671
#             quote.USD.percent_change_30d  18.31583
#             quote.USD.percent_change_60d  19.56796
#             quote.USD.percent_change_90d  12.52845
# Litecoin    quote.USD.percent_change_1h   -0.13486
#             quote.USD.percent_change_24h  -1.55648
#             quote.USD.percent_change_7d    4.35185
#             quote.USD.percent_change_30d   4.36772
#             quote.USD.percent_change_60d  -2.85919
#             quote.USD.percent_change_90d  -2.83082
# Polkadot    quote.USD.percent_change_1h    0.00854
#             quote.USD.percent_change_24h   0.71942
#             quote.USD.percent_change_7d   -0.09588
#             quote.USD.percent_change_30d -10.72570
#             quote.USD.percent_change_60d -15.97082
#             quote.USD.percent_change_90d -26.63008
# Binance USD quote.USD.percent_change_1h    0.01355
#             quote.USD.percent_change_24h   0.02433
#             quote.USD.percent_change_7d    0.01091
#             quote.USD.percent_change_30d   0.00973
#             quote.USD.percent_change_60d   0.01142
#             quote.USD.percent_change_90d  -0.02096
# Shiba Inu   quote.USD.percent_change_1h    0.12475
#             quote.USD.percent_change_24h   2.91830
#             quote.USD.percent_change_7d   -0.26114
#             quote.USD.percent_change_30d -16.04656
#             quote.USD.percent_change_60d -19.07900
#             quote.USD.percent_change_90d -32.66842

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
index = pd.Index(range(90))

df6 = df5.reset_index()
df6
# Out:
#            name                       level_1    values
# 0       Bitcoin   quote.USD.percent_change_1h  -0.07406
# 1       Bitcoin  quote.USD.percent_change_24h   0.38359
# 2       Bitcoin   quote.USD.percent_change_7d  -1.23477
# 3       Bitcoin  quote.USD.percent_change_30d  -3.41061
# 4       Bitcoin  quote.USD.percent_change_60d  -5.20092
# 5       Bitcoin  quote.USD.percent_change_90d  10.05139
# 6      Ethereum   quote.USD.percent_change_1h  -0.06606
# 7      Ethereum  quote.USD.percent_change_24h   0.77458
# 8      Ethereum   quote.USD.percent_change_7d   0.01458
# 9      Ethereum  quote.USD.percent_change_30d  -2.99995
# 10     Ethereum  quote.USD.percent_change_60d   0.07914
# 11     Ethereum  quote.USD.percent_change_90d   9.75773
# 12       Tether   quote.USD.percent_change_1h   0.00042
# 13       Tether  quote.USD.percent_change_24h   0.00724
# 14       Tether   quote.USD.percent_change_7d  -0.00517
# 15       Tether  quote.USD.percent_change_30d   0.00387
# 16       Tether  quote.USD.percent_change_60d  -0.07720
# 17       Tether  quote.USD.percent_change_90d   0.01354
# 18          BNB   quote.USD.percent_change_1h  -0.12146
# 19          BNB  quote.USD.percent_change_24h   0.87049
# 20          BNB   quote.USD.percent_change_7d  -1.35923
# 21          BNB  quote.USD.percent_change_30d  -6.90445
# 22          BNB  quote.USD.percent_change_60d  -6.26609
# 23          BNB  quote.USD.percent_change_90d  -0.62251
# 24     USD Coin   quote.USD.percent_change_1h   0.00188
# 25     USD Coin  quote.USD.percent_change_24h   0.01472
# 26     USD Coin   quote.USD.percent_change_7d  -0.00143
# 27     USD Coin  quote.USD.percent_change_30d  -0.00841
# 28     USD Coin  quote.USD.percent_change_60d   0.10089
# 29     USD Coin  quote.USD.percent_change_90d  -0.00291
# 30          XRP   quote.USD.percent_change_1h   0.08548
# 31          XRP  quote.USD.percent_change_24h   0.75239
# 32          XRP   quote.USD.percent_change_7d   8.00380
# 33          XRP  quote.USD.percent_change_30d  -2.35462
# 34          XRP  quote.USD.percent_change_60d   3.67541
# 35          XRP  quote.USD.percent_change_90d  17.87407
# 36      Cardano   quote.USD.percent_change_1h  -0.10103
# 37      Cardano  quote.USD.percent_change_24h   1.99555
# 38      Cardano   quote.USD.percent_change_7d   0.12268
# 39      Cardano  quote.USD.percent_change_30d  -7.09123
# 40      Cardano  quote.USD.percent_change_60d  -1.07225
# 41      Cardano  quote.USD.percent_change_90d  -6.12692
# 42     Dogecoin   quote.USD.percent_change_1h  -0.06505
# 43     Dogecoin  quote.USD.percent_change_24h   1.15090
# 44     Dogecoin   quote.USD.percent_change_7d   1.32000
# 45     Dogecoin  quote.USD.percent_change_30d  -9.24916
# 46     Dogecoin  quote.USD.percent_change_60d  -5.73953
# 47     Dogecoin  quote.USD.percent_change_90d -14.43667
# 48      Polygon   quote.USD.percent_change_1h   0.00548
# 49      Polygon  quote.USD.percent_change_24h   1.72971
# 50      Polygon   quote.USD.percent_change_7d   1.37163
# 51      Polygon  quote.USD.percent_change_30d -14.95408
# 52      Polygon  quote.USD.percent_change_60d -23.28082
# 53      Polygon  quote.USD.percent_change_90d -36.89650
# 54       Solana   quote.USD.percent_change_1h  -0.30624
# 55       Solana  quote.USD.percent_change_24h  -0.44742
# 56       Solana   quote.USD.percent_change_7d  -6.87745
# 57       Solana  quote.USD.percent_change_30d -10.36284
# 58       Solana  quote.USD.percent_change_60d -11.98263
# 59       Solana  quote.USD.percent_change_90d -21.45123
# 60         TRON   quote.USD.percent_change_1h  -0.41186
# 61         TRON  quote.USD.percent_change_24h   3.86754
# 62         TRON   quote.USD.percent_change_7d  11.23671
# 63         TRON  quote.USD.percent_change_30d  18.31583
# 64         TRON  quote.USD.percent_change_60d  19.56796
# 65         TRON  quote.USD.percent_change_90d  12.52845
# 66     Litecoin   quote.USD.percent_change_1h  -0.13486
# 67     Litecoin  quote.USD.percent_change_24h  -1.55648
# 68     Litecoin   quote.USD.percent_change_7d   4.35185
# 69     Litecoin  quote.USD.percent_change_30d   4.36772
# 70     Litecoin  quote.USD.percent_change_60d  -2.85919
# 71     Litecoin  quote.USD.percent_change_90d  -2.83082
# 72     Polkadot   quote.USD.percent_change_1h   0.00854
# 73     Polkadot  quote.USD.percent_change_24h   0.71942
# 74     Polkadot   quote.USD.percent_change_7d  -0.09588
# 75     Polkadot  quote.USD.percent_change_30d -10.72570
# 76     Polkadot  quote.USD.percent_change_60d -15.97082
# 77     Polkadot  quote.USD.percent_change_90d -26.63008
# 78  Binance USD   quote.USD.percent_change_1h   0.01355
# 79  Binance USD  quote.USD.percent_change_24h   0.02433
# 80  Binance USD   quote.USD.percent_change_7d   0.01091
# 81  Binance USD  quote.USD.percent_change_30d   0.00973
# 82  Binance USD  quote.USD.percent_change_60d   0.01142
# 83  Binance USD  quote.USD.percent_change_90d  -0.02096
# 84    Shiba Inu   quote.USD.percent_change_1h   0.12475
# 85    Shiba Inu  quote.USD.percent_change_24h   2.91830
# 86    Shiba Inu   quote.USD.percent_change_7d  -0.26114
# 87    Shiba Inu  quote.USD.percent_change_30d -16.04656
# 88    Shiba Inu  quote.USD.percent_change_60d -19.07900
# 89    Shiba Inu  quote.USD.percent_change_90d -32.66842

# %%
df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#            name                percent_change    values
# 0       Bitcoin   quote.USD.percent_change_1h  -0.07406
# 1       Bitcoin  quote.USD.percent_change_24h   0.38359
# 2       Bitcoin   quote.USD.percent_change_7d  -1.23477
# 3       Bitcoin  quote.USD.percent_change_30d  -3.41061
# 4       Bitcoin  quote.USD.percent_change_60d  -5.20092
# 5       Bitcoin  quote.USD.percent_change_90d  10.05139
# 6      Ethereum   quote.USD.percent_change_1h  -0.06606
# 7      Ethereum  quote.USD.percent_change_24h   0.77458
# 8      Ethereum   quote.USD.percent_change_7d   0.01458
# 9      Ethereum  quote.USD.percent_change_30d  -2.99995
# 10     Ethereum  quote.USD.percent_change_60d   0.07914
# 11     Ethereum  quote.USD.percent_change_90d   9.75773
# 12       Tether   quote.USD.percent_change_1h   0.00042
# 13       Tether  quote.USD.percent_change_24h   0.00724
# 14       Tether   quote.USD.percent_change_7d  -0.00517
# 15       Tether  quote.USD.percent_change_30d   0.00387
# 16       Tether  quote.USD.percent_change_60d  -0.07720
# 17       Tether  quote.USD.percent_change_90d   0.01354
# 18          BNB   quote.USD.percent_change_1h  -0.12146
# 19          BNB  quote.USD.percent_change_24h   0.87049
# 20          BNB   quote.USD.percent_change_7d  -1.35923
# 21          BNB  quote.USD.percent_change_30d  -6.90445
# 22          BNB  quote.USD.percent_change_60d  -6.26609
# 23          BNB  quote.USD.percent_change_90d  -0.62251
# 24     USD Coin   quote.USD.percent_change_1h   0.00188
# 25     USD Coin  quote.USD.percent_change_24h   0.01472
# 26     USD Coin   quote.USD.percent_change_7d  -0.00143
# 27     USD Coin  quote.USD.percent_change_30d  -0.00841
# 28     USD Coin  quote.USD.percent_change_60d   0.10089
# 29     USD Coin  quote.USD.percent_change_90d  -0.00291
# 30          XRP   quote.USD.percent_change_1h   0.08548
# 31          XRP  quote.USD.percent_change_24h   0.75239
# 32          XRP   quote.USD.percent_change_7d   8.00380
# 33          XRP  quote.USD.percent_change_30d  -2.35462
# 34          XRP  quote.USD.percent_change_60d   3.67541
# 35          XRP  quote.USD.percent_change_90d  17.87407
# 36      Cardano   quote.USD.percent_change_1h  -0.10103
# 37      Cardano  quote.USD.percent_change_24h   1.99555
# 38      Cardano   quote.USD.percent_change_7d   0.12268
# 39      Cardano  quote.USD.percent_change_30d  -7.09123
# 40      Cardano  quote.USD.percent_change_60d  -1.07225
# 41      Cardano  quote.USD.percent_change_90d  -6.12692
# 42     Dogecoin   quote.USD.percent_change_1h  -0.06505
# 43     Dogecoin  quote.USD.percent_change_24h   1.15090
# 44     Dogecoin   quote.USD.percent_change_7d   1.32000
# 45     Dogecoin  quote.USD.percent_change_30d  -9.24916
# 46     Dogecoin  quote.USD.percent_change_60d  -5.73953
# 47     Dogecoin  quote.USD.percent_change_90d -14.43667
# 48      Polygon   quote.USD.percent_change_1h   0.00548
# 49      Polygon  quote.USD.percent_change_24h   1.72971
# 50      Polygon   quote.USD.percent_change_7d   1.37163
# 51      Polygon  quote.USD.percent_change_30d -14.95408
# 52      Polygon  quote.USD.percent_change_60d -23.28082
# 53      Polygon  quote.USD.percent_change_90d -36.89650
# 54       Solana   quote.USD.percent_change_1h  -0.30624
# 55       Solana  quote.USD.percent_change_24h  -0.44742
# 56       Solana   quote.USD.percent_change_7d  -6.87745
# 57       Solana  quote.USD.percent_change_30d -10.36284
# 58       Solana  quote.USD.percent_change_60d -11.98263
# 59       Solana  quote.USD.percent_change_90d -21.45123
# 60         TRON   quote.USD.percent_change_1h  -0.41186
# 61         TRON  quote.USD.percent_change_24h   3.86754
# 62         TRON   quote.USD.percent_change_7d  11.23671
# 63         TRON  quote.USD.percent_change_30d  18.31583
# 64         TRON  quote.USD.percent_change_60d  19.56796
# 65         TRON  quote.USD.percent_change_90d  12.52845
# 66     Litecoin   quote.USD.percent_change_1h  -0.13486
# 67     Litecoin  quote.USD.percent_change_24h  -1.55648
# 68     Litecoin   quote.USD.percent_change_7d   4.35185
# 69     Litecoin  quote.USD.percent_change_30d   4.36772
# 70     Litecoin  quote.USD.percent_change_60d  -2.85919
# 71     Litecoin  quote.USD.percent_change_90d  -2.83082
# 72     Polkadot   quote.USD.percent_change_1h   0.00854
# 73     Polkadot  quote.USD.percent_change_24h   0.71942
# 74     Polkadot   quote.USD.percent_change_7d  -0.09588
# 75     Polkadot  quote.USD.percent_change_30d -10.72570
# 76     Polkadot  quote.USD.percent_change_60d -15.97082
# 77     Polkadot  quote.USD.percent_change_90d -26.63008
# 78  Binance USD   quote.USD.percent_change_1h   0.01355
# 79  Binance USD  quote.USD.percent_change_24h   0.02433
# 80  Binance USD   quote.USD.percent_change_7d   0.01091
# 81  Binance USD  quote.USD.percent_change_30d   0.00973
# 82  Binance USD  quote.USD.percent_change_60d   0.01142
# 83  Binance USD  quote.USD.percent_change_90d  -0.02096
# 84    Shiba Inu   quote.USD.percent_change_1h   0.12475
# 85    Shiba Inu  quote.USD.percent_change_24h   2.91830
# 86    Shiba Inu   quote.USD.percent_change_7d  -0.26114
# 87    Shiba Inu  quote.USD.percent_change_30d -16.04656
# 88    Shiba Inu  quote.USD.percent_change_60d -19.07900
# 89    Shiba Inu  quote.USD.percent_change_90d -32.66842

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d', 'quote.USD.percent_change_30d', 'quote.USD.percent_change_60d', 'quote.USD.percent_change_90d'],['1h','24h','7d','30d','60d','90d'])
df7
# Out:
#            name percent_change    values
# 0       Bitcoin             1h  -0.07406
# 1       Bitcoin            24h   0.38359
# 2       Bitcoin             7d  -1.23477
# 3       Bitcoin            30d  -3.41061
# 4       Bitcoin            60d  -5.20092
# 5       Bitcoin            90d  10.05139
# 6      Ethereum             1h  -0.06606
# 7      Ethereum            24h   0.77458
# 8      Ethereum             7d   0.01458
# 9      Ethereum            30d  -2.99995
# 10     Ethereum            60d   0.07914
# 11     Ethereum            90d   9.75773
# 12       Tether             1h   0.00042
# 13       Tether            24h   0.00724
# 14       Tether             7d  -0.00517
# 15       Tether            30d   0.00387
# 16       Tether            60d  -0.07720
# 17       Tether            90d   0.01354
# 18          BNB             1h  -0.12146
# 19          BNB            24h   0.87049
# 20          BNB             7d  -1.35923
# 21          BNB            30d  -6.90445
# 22          BNB            60d  -6.26609
# 23          BNB            90d  -0.62251
# 24     USD Coin             1h   0.00188
# 25     USD Coin            24h   0.01472
# 26     USD Coin             7d  -0.00143
# 27     USD Coin            30d  -0.00841
# 28     USD Coin            60d   0.10089
# 29     USD Coin            90d  -0.00291
# 30          XRP             1h   0.08548
# 31          XRP            24h   0.75239
# 32          XRP             7d   8.00380
# 33          XRP            30d  -2.35462
# 34          XRP            60d   3.67541
# 35          XRP            90d  17.87407
# 36      Cardano             1h  -0.10103
# 37      Cardano            24h   1.99555
# 38      Cardano             7d   0.12268
# 39      Cardano            30d  -7.09123
# 40      Cardano            60d  -1.07225
# 41      Cardano            90d  -6.12692
# 42     Dogecoin             1h  -0.06505
# 43     Dogecoin            24h   1.15090
# 44     Dogecoin             7d   1.32000
# 45     Dogecoin            30d  -9.24916
# 46     Dogecoin            60d  -5.73953
# 47     Dogecoin            90d -14.43667
# 48      Polygon             1h   0.00548
# 49      Polygon            24h   1.72971
# 50      Polygon             7d   1.37163
# 51      Polygon            30d -14.95408
# 52      Polygon            60d -23.28082
# 53      Polygon            90d -36.89650
# 54       Solana             1h  -0.30624
# 55       Solana            24h  -0.44742
# 56       Solana             7d  -6.87745
# 57       Solana            30d -10.36284
# 58       Solana            60d -11.98263
# 59       Solana            90d -21.45123
# 60         TRON             1h  -0.41186
# 61         TRON            24h   3.86754
# 62         TRON             7d  11.23671
# 63         TRON            30d  18.31583
# 64         TRON            60d  19.56796
# 65         TRON            90d  12.52845
# 66     Litecoin             1h  -0.13486
# 67     Litecoin            24h  -1.55648
# 68     Litecoin             7d   4.35185
# 69     Litecoin            30d   4.36772
# 70     Litecoin            60d  -2.85919
# 71     Litecoin            90d  -2.83082
# 72     Polkadot             1h   0.00854
# 73     Polkadot            24h   0.71942
# 74     Polkadot             7d  -0.09588
# 75     Polkadot            30d -10.72570
# 76     Polkadot            60d -15.97082
# 77     Polkadot            90d -26.63008
# 78  Binance USD             1h   0.01355
# 79  Binance USD            24h   0.02433
# 80  Binance USD             7d   0.01091
# 81  Binance USD            30d   0.00973
# 82  Binance USD            60d   0.01142
# 83  Binance USD            90d  -0.02096
# 84    Shiba Inu             1h   0.12475
# 85    Shiba Inu            24h   2.91830
# 86    Shiba Inu             7d  -0.26114
# 87    Shiba Inu            30d -16.04656
# 88    Shiba Inu            60d -19.07900
# 89    Shiba Inu            90d -32.66842

# %%
df8 = df7.rename(columns={'percent_change': 'time_period'})
df8 = df8.rename(columns={'values': 'percent_change'})
df8
# Out:
#            name time_period  percent_change
# 0       Bitcoin          1h        -0.07406
# 1       Bitcoin         24h         0.38359
# 2       Bitcoin          7d        -1.23477
# 3       Bitcoin         30d        -3.41061
# 4       Bitcoin         60d        -5.20092
# 5       Bitcoin         90d        10.05139
# 6      Ethereum          1h        -0.06606
# 7      Ethereum         24h         0.77458
# 8      Ethereum          7d         0.01458
# 9      Ethereum         30d        -2.99995
# 10     Ethereum         60d         0.07914
# 11     Ethereum         90d         9.75773
# 12       Tether          1h         0.00042
# 13       Tether         24h         0.00724
# 14       Tether          7d        -0.00517
# 15       Tether         30d         0.00387
# 16       Tether         60d        -0.07720
# 17       Tether         90d         0.01354
# 18          BNB          1h        -0.12146
# 19          BNB         24h         0.87049
# 20          BNB          7d        -1.35923
# 21          BNB         30d        -6.90445
# 22          BNB         60d        -6.26609
# 23          BNB         90d        -0.62251
# 24     USD Coin          1h         0.00188
# 25     USD Coin         24h         0.01472
# 26     USD Coin          7d        -0.00143
# 27     USD Coin         30d        -0.00841
# 28     USD Coin         60d         0.10089
# 29     USD Coin         90d        -0.00291
# 30          XRP          1h         0.08548
# 31          XRP         24h         0.75239
# 32          XRP          7d         8.00380
# 33          XRP         30d        -2.35462
# 34          XRP         60d         3.67541
# 35          XRP         90d        17.87407
# 36      Cardano          1h        -0.10103
# 37      Cardano         24h         1.99555
# 38      Cardano          7d         0.12268
# 39      Cardano         30d        -7.09123
# 40      Cardano         60d        -1.07225
# 41      Cardano         90d        -6.12692
# 42     Dogecoin          1h        -0.06505
# 43     Dogecoin         24h         1.15090
# 44     Dogecoin          7d         1.32000
# 45     Dogecoin         30d        -9.24916
# 46     Dogecoin         60d        -5.73953
# 47     Dogecoin         90d       -14.43667
# 48      Polygon          1h         0.00548
# 49      Polygon         24h         1.72971
# 50      Polygon          7d         1.37163
# 51      Polygon         30d       -14.95408
# 52      Polygon         60d       -23.28082
# 53      Polygon         90d       -36.89650
# 54       Solana          1h        -0.30624
# 55       Solana         24h        -0.44742
# 56       Solana          7d        -6.87745
# 57       Solana         30d       -10.36284
# 58       Solana         60d       -11.98263
# 59       Solana         90d       -21.45123
# 60         TRON          1h        -0.41186
# 61         TRON         24h         3.86754
# 62         TRON          7d        11.23671
# 63         TRON         30d        18.31583
# 64         TRON         60d        19.56796
# 65         TRON         90d        12.52845
# 66     Litecoin          1h        -0.13486
# 67     Litecoin         24h        -1.55648
# 68     Litecoin          7d         4.35185
# 69     Litecoin         30d         4.36772
# 70     Litecoin         60d        -2.85919
# 71     Litecoin         90d        -2.83082
# 72     Polkadot          1h         0.00854
# 73     Polkadot         24h         0.71942
# 74     Polkadot          7d        -0.09588
# 75     Polkadot         30d       -10.72570
# 76     Polkadot         60d       -15.97082
# 77     Polkadot         90d       -26.63008
# 78  Binance USD          1h         0.01355
# 79  Binance USD         24h         0.02433
# 80  Binance USD          7d         0.01091
# 81  Binance USD         30d         0.00973
# 82  Binance USD         60d         0.01142
# 83  Binance USD         90d        -0.02096
# 84    Shiba Inu          1h         0.12475
# 85    Shiba Inu         24h         2.91830
# 86    Shiba Inu          7d        -0.26114
# 87    Shiba Inu         30d       -16.04656
# 88    Shiba Inu         60d       -19.07900
# 89    Shiba Inu         90d       -32.66842

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')

# %%
# there was not enough data collected to properly visualize this example but I wrote the code anyway

df9 = df72[['name','quote.USD.price','timestamp']]
df9 = df9.query("name == 'Bitcoin'")
df9
# Out:
#        name  quote.USD.price                   timestamp
# 0   Bitcoin      26806.88052  2023-05-18 21:30:43.299581
# 15  Bitcoin      26849.35726  2023-05-18 21:32:08.024563
# 30  Bitcoin      26830.35474  2023-05-18 21:33:08.305762
# 45  Bitcoin      26860.29589  2023-05-22 23:53:37.283961
# 60  Bitcoin      26861.47332  2023-05-22 23:54:37.763551

# %%
sns.set_theme(style="darkgrid")
sns.lineplot(x='timestamp', y='quote.USD.price', data=df9)
# Out:
# <Axes: xlabel='timestamp', ylabel='quote.USD.price'>
